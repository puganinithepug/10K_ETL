# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import LinearSVC
from sklearn.metrics import confusion_matrix
from sklearn.calibration import CalibratedClassifierCV

from sklearn.model_selection import train_test_split

import numpy as np

# imports for pipeline to run
import requests
import re
import unicodedata
import os
import warnings

import logging

import argparse

import math

import matplotlib_inline

# for fetching previosu pipeline steps
import importlib

# previous pipeline step
import Sort_10K_by_Context_W3 as SortCxt

# updated
importlib.reload(SortCxt)

# options:
# word embeddings
# bag-of-words
# tf idf, confusion matrix to pick best classifier for csv annotation 

# using NLP for:

# task 1 - nlp
# use bal_sheet_example.csv for training
# copy bal_sheet_{ticker}_data.csv to nlp_bal_sheet_{ticker}_data.csv 
# annotate nlp_bal_sheet_{ticker}_data.csv with category column based on training 
# if there are labels in the nlp_bal_sheet_{ticker}_data.csv that are not present in the bal_sheet_example.csv, add (label, value, category) to the bal_sheet_example.csv where category is hypothesized

# task 2
# use income_&_cashflow_example.csv for training 
# copy inc_cf_{ticker}.csv to nlp_inc_cf_{ticker}.csv 
# annotate nlp_inc_cf_{ticker}.csv with statement column and category column based on training 
# if there are labels in the nlp_inc_cf_{ticker}.csv that are not present in the income_&_cashflow_example.csv, add (label, value, category) to the income_&_cashflow_example.csv where category is hypothesized

# task 3 - no nlp
# separate nlp_inc_cf_{ticker}.csv into two csvs: nlp_inc_{ticker}.csv and nlp_cf_{ticker}.csv based on statement column (if "income" -> nlp_inc_{ticker}.csv, if "cashflow" -> nlp_cf_{ticker}.csv)

# task 4 - no nlp
# reconstruct balance sheet from nlp_bal_sheet_{ticker}_data.csv, income statement from nlp_inc_{ticker}.csv, cashflow statement from nlp_cf_{ticker}.csv
# by placing items with the same value in category column together, ordered by size of value (smaller value first -> biggest listed last)

# parser
def parse_args():
    parser = argparse.ArgumentParser(description="Get confidence threshold")
    parser.add_argument("--confidence", help="confidence threshold", default=None)
    
    args, _ = parser.parse_known_args()

    while True:
        if not args.confidence:
            args.confidence = input("Confidence threshold (0.0-1.0): ")
        
        try:
            confidence_value = float(args.confidence)
            
            if 0.0 <= confidence_value <= 1.0:
                args.confidence = confidence_value
                break
            else:
                print("Error: Confidence threshold must be between 0 and 1")
                args.confidence = None  # Reset to retry
                
        except ValueError:
            print("Error: Enter a numeric value (e.g., 0.5)")
            args.confidence = None  # Reset to retry
    
    return args

def camelcase_tokenizer(text):
    # Split on camelCase boundaries
    tokens = re.findall(r'[A-Z]+(?=[A-Z][a-z]|\b)|[A-Z][a-z]+', text)
    return ' '.join(tokens)

def classify_income_cashflow_statement_type(train_df, test_df):
    # input:
    #     train_df: DataFrame with columns ['label', 'value', 'statement', 'category']
    #               (from income_&_cashflow_example.csv)
    #     test_df: DataFrame with columns ['label', 'value']
    
    # output:
    #     dictionary with classifier and "statement" predictions
    
    vectorizer = TfidfVectorizer(
        # since label items look like this: IncrementalCommonSharesAttributableToShareBasedPaymentArrangements
        tokenizer=camelcase_tokenizer,
        lowercase=False,
        min_df=1,           
        ngram_range=(1, 15)
    )

    X_full = vectorizer.fit_transform(train_df['label'])
    y_full = train_df['statement']  # "income" or "cashflow"

    # split into training and validation data
    X_train, X_val, y_train, y_val = train_test_split(X_full, y_full, test_size=0.3, random_state=0)
 
    # choose best for binary classification
    classifiers = {
        "LogisticRegression": LogisticRegression(random_state=0, max_iter=1000),
        #"LinearSVC": CalibratedClassifierCV(LinearSVC(random_state=0, max_iter=2000, dual=False), cv=2)
    }
    
    results = {}
    best_val_accuracy = -1
    best_classifier_name = None
    best_model = None
    
    for name, clf in classifiers.items():
        # Train on training set
        clf.fit(X_train, y_train)
        
        # Evaluate on validation set (unseen during training)
        val_accuracy = clf.score(X_val, y_val)
        
        results[name] = {
            'model': clf,
            'train_accuracy': clf.score(X_train, y_train),
            'val_accuracy': val_accuracy
        }
        
        print(f"{name}: train={clf.score(X_train, y_train):.4f}, val={val_accuracy:.4f}")
        
        if val_accuracy > best_val_accuracy:
            best_val_accuracy = val_accuracy
            best_classifier_name = name
            best_model = clf
    
    # Retrain best model on full training data
    best_model.fit(X_full, y_full)
    
    X_test = vectorizer.transform(test_df['label'])
    test_predictions = best_model.predict(X_test)
    test_probabilities = best_model.predict_proba(X_test)
    
    return {
        "best_classifier": best_classifier_name,
        "best_model": best_model,
        "vectorizer": vectorizer,
        "predictions": test_predictions,
        "probabilities": test_probabilities,
        "results": results,
        "val_accuracy": best_val_accuracy
    }

def classify_income_cashflow_category(train_df, test_df):
    # classify the category within income or cashflow statements.
    # input:
    #     train_df: DataFrame with columns ['label', 'value', 'statement', 'category']
    #     test_df: DataFrame with columns ['label', 'value', 'statement']  
    #              (statement added from previous step)
    # output:
    #     dictionary with classifier and "category" predictions
    vectorizer = TfidfVectorizer(
        # since label items look like this: IncrementalCommonSharesAttributableToShareBasedPaymentArrangements
        tokenizer=camelcase_tokenizer,
        lowercase=False,
        min_df=1,           
        ngram_range=(1, 15)
    )

    X_full = vectorizer.fit_transform(train_df['label'])
    y_full = train_df['category']
    
    # split into training and validation data
    X_train, X_val, y_train, y_val = train_test_split(X_full, y_full, test_size=0.3, random_state=0)
 
    classifiers = {
        "LogisticRegression": LogisticRegression(random_state=0, max_iter=1000),
        "MultinomialNB": MultinomialNB(),
        "DecisionTreeClassifier": DecisionTreeClassifier(random_state=0, max_depth=5),
        # "LinearSVC": CalibratedClassifierCV(LinearSVC(random_state=0, max_iter=2000, dual=False), cv=2)
    }
    
    results = {}
    best_val_accuracy = -1
    best_classifier_name = None
    best_model = None
    
    for name, clf in classifiers.items():
        # Train on training set
        clf.fit(X_train, y_train)
        
        # Evaluate on validation set (unseen during training)
        val_accuracy = clf.score(X_val, y_val)
        
        results[name] = {
            'model': clf,
            'train_accuracy': clf.score(X_train, y_train),
            'val_accuracy': val_accuracy
        }
        
        print(f"{name}: train={clf.score(X_train, y_train):.4f}, val={val_accuracy:.4f}")
        
        if val_accuracy > best_val_accuracy:
            best_val_accuracy = val_accuracy
            best_classifier_name = name
            best_model = clf
    
    # Retrain best model on full training data
    best_model.fit(X_full, y_full)
    
    X_test = vectorizer.transform(test_df['label'])
    test_predictions = best_model.predict(X_test)
    test_probabilities = best_model.predict_proba(X_test)
    
    return {
        "best_classifier": best_classifier_name,
        "best_model": best_model,
        "vectorizer": vectorizer,
        "predictions": test_predictions,
        "probabilities": test_probabilities,
        "results": results,
        "val_accuracy": best_val_accuracy
    }

def classify_balance_sheet(train_df, test_df): 
    # input:
    #     train_df: DataFrame with columns ['label', 'value', 'category']
    #               (from bal_sheet_example.csv)
    #     test_df: DataFrame with columns ['label', 'value'] 
    #              (from bal_sheet_{ticker}_data.csv, no category yet)
    
    # output:
    #     dictionary with best classifier, vectorizer, and predictions
    
    vectorizer = TfidfVectorizer(
        # since label items look like this: IncrementalCommonSharesAttributableToShareBasedPaymentArrangements
        tokenizer=camelcase_tokenizer,
        lowercase=False,
        min_df=1,           
        ngram_range=(1, 15)
    )

    # step 1 - data
    X_full = vectorizer.fit_transform(train_df['label'])
    y_full = train_df['category']
    
    # split: 70% train, 30% validate
    X_train, X_val, y_train, y_val = train_test_split(X_full, y_full, test_size=0.3, random_state=0)
    
    # step 2 - classifiers
    classifiers = {
        "LogisticRegression": LogisticRegression(random_state=0, max_iter=1000),
        "MultinomialNB": MultinomialNB(),
        "DecisionTreeClassifier": DecisionTreeClassifier(random_state=0, max_depth=5),
        #"LinearSVC": CalibratedClassifierCV(LinearSVC(random_state=0, max_iter=2000, dual=False), cv=2)
    }
    
    # step 3 - train and validate    
    results = {}
    best_val_accuracy = -1
    best_classifier_name = None
    best_model = None
    
    for name, clf in classifiers.items():
        # train on training set
        clf.fit(X_train, y_train)

        val_accuracy = clf.score(X_val, y_val)

        results[name] = {
            'model': clf,
            'train_accuracy': clf.score(X_train, y_train),
            'val_accuracy': val_accuracy
        }
        print(f"{name}: train={clf.score(X_train, y_train):.4f}, val={val_accuracy:.4f}")
        
        # pick best classifier
        if val_accuracy > best_val_accuracy:
            best_val_accuracy = val_accuracy
            best_classifier_name = name
            best_model = clf

    # retrain best model on full data set
    best_model.fit(X_full, y_full)

    # step 4 - predict on test data
    X_test = vectorizer.transform(test_df['label'])
    test_predictions = best_model.predict(X_test)
    
    # step 5 - prediction probabilities - to flag uncertain predictions
    test_probabilities = best_model.predict_proba(X_test)

    return {
        "best_classifier": best_classifier_name,
        "best_model": best_model,
        "vectorizer": vectorizer,
        "predictions": test_predictions,
        "probabilities": test_probabilities,
        "results": results,
        "training_accuracy": best_val_accuracy
    }

def flag_uncertain_predictions(original_train_df, annotated_test_df, 
                             confidence_threshold=0.5, output_file=None):
    # input:
    #     original_train_df: original training CSV (for reference only)
    #     annotated_test_df: annotated test CSV with predictions and confidence scores
    #     confidence_threshold: predictions below this threshold are flagged as uncertain
    #     output_file: path to save uncertain predictions CSV
    
    # output:
    #     DataFrame containing only uncertain predictions
    
    # identify uncertain predictions
    if 'statement' in annotated_test_df.columns:
        # income/cashflow case - if either statement or category confidence is below threshold
        uncertain_mask = (
            (annotated_test_df['statement_confidence'] < confidence_threshold) |
            (annotated_test_df['category_confidence'] < confidence_threshold)
        )
    else:
        # balance sheet case: check if category confidence is below threshold
        uncertain_mask = annotated_test_df['prediction_confidence'] < confidence_threshold

    # copy uncertain predictions into a separate file
    uncertain_df = annotated_test_df[uncertain_mask].copy()

    # if there re no uncertain predictions, return the original dataset
    if len(uncertain_df) == 0:
        print(f"✓ No uncertain predictions found (threshold: {confidence_threshold})")
        return pd.DataFrame()
    
    # Sort by confidence (lowest first) so highest priority uncertain cases appear first
    if 'statement' in uncertain_df.columns:
        # Use minimum confidence of both columns
        uncertain_df['min_confidence'] = uncertain_df[['statement_confidence', 'category_confidence']].min(axis=1)
        uncertain_df = uncertain_df.sort_values('min_confidence')
        uncertain_df = uncertain_df.drop(columns=['min_confidence'])
    else:
        uncertain_df = uncertain_df.sort_values('prediction_confidence')
    
    #summary
    print(f"\n⚠ Found {len(uncertain_df)} uncertain predictions (threshold: {confidence_threshold}):")
    print(f"  Require manual review and annotation.\n")
    
    # Select columns to display
    cols_to_display = ['label', 'value']
    if 'statement' in uncertain_df.columns:
        cols_to_display.extend(['statement', 'statement_confidence', 'category', 'category_confidence'])
    else:
        cols_to_display.extend(['category', 'prediction_confidence'])
    
    print(uncertain_df[cols_to_display].to_string(index=False))
    
    # Save to CSV if output file specified
    if output_file:
        uncertain_df.to_csv(output_file, index=False)
        print(f"\n✓ Uncertain predictions saved to: {output_file}")
        print(f"  Please review and manually annotate these predictions.")
    
    return uncertain_df
    
def separate_income_cashflow(ticker):
    
    # split nlp_inc_cf_{ticker}.csv into two files based on 'statement' column.
    
    df = pd.read_csv(f'nlp_inc_cf_{ticker}.csv')
    
    # Filter by statement type
    income_df = df[df['statement'].str.lower() == 'income'].copy()
    cashflow_df = df[df['statement'].str.lower() == 'cashflow'].copy()
    
    # drop the 'statement' column
    income_df = income_df.drop(columns=['statement'])
    cashflow_df = cashflow_df.drop(columns=['statement'])

    # sort by category and value so that it resembles proper format
    income_df = income_df.sort_values(by=['category', 'value']).reset_index(drop=True)
    cashflow_df = cashflow_df.sort_values(by=['category', 'value']).reset_index(drop=True)
    
    return income_df, cashflow_df

def main():

    # Run previous pipeline steps
    ticker = SortCxt.main()

    args = parse_args()

    confidence_threshold = float(args.confidence)

    # task 1
    # get training dataset for balance sheet # label, value, category
    bal_sheet_train = pd.read_csv('bal_sheet_example.csv')

    # print("Testing tokenizer on first 5 labels:\n")
    # for i, label in enumerate(bal_sheet_train['label'].head()):
    #     tokens = camelcase_tokenizer(label)
    #     print(f"{i+1}. {label}")
    #     print(f"   Tokens: {tokens}")
    #     print(f"   Count: {len(tokens)}\n")

    # get test dataset # label, value
    bal_sheet_test = pd.read_csv(f'bal_sheet_{ticker}_data.csv') 

    # classify labels by balance sheet categories
    bal_sheet_results = classify_balance_sheet(bal_sheet_train, bal_sheet_test)

    # add predictions to test data (balance sheet)
    bal_sheet_test['category'] = bal_sheet_results['predictions']
    bal_sheet_test['prediction_confidence'] = bal_sheet_results['probabilities'].max(axis=1)

    # sort by category and value so that it resembles proper format
    bal_sheet_test= bal_sheet_test.sort_values(by=['category', 'value']).reset_index(drop=True)
    
    # save annotated balance sheet file
    bal_sheet_test.to_csv(f'nlp_bal_sheet_{ticker}_data.csv', index=False)

    # task 2
    # get training dataset for income and cashflow statement # label, value, statement, category
    income_cashflow_train = pd.read_csv('income_&_cashflow_example.csv')

    # get test dataset # label, value
    income_cashflow_test = pd.read_csv(f'inc_cf_{ticker}_data.csv')

    # classify statement type
    statement_results = classify_income_cashflow_statement_type(income_cashflow_train, income_cashflow_test)
    income_cashflow_test['statement'] = statement_results['predictions']
    income_cashflow_test['statement_confidence'] = statement_results['probabilities'].max(axis=1)
    
    # classify category
    category_results = classify_income_cashflow_category(income_cashflow_train, income_cashflow_test)
    income_cashflow_test['category'] = category_results['predictions']
    income_cashflow_test['category_confidence'] = category_results['probabilities'].max(axis=1)
    
    # save annotated file
    income_cashflow_test.to_csv(f'nlp_inc_cf_{ticker}.csv', index=False)

    # get df's for income and cashflow
    income_df, cashflow_df = separate_income_cashflow(ticker)

    # write to separate csv's income and cashflow
    income_df.to_csv(f'nlp_inc_{ticker}.csv', index=False)
    print(f"Income statement: {len(income_df)} rows in nlp_inc_{ticker}.csv")

    cashflow_df.to_csv(f'nlp_cf_{ticker}.csv', index=False)
    print(f"Cashflow statement: {len(cashflow_df)} rows in nlp_cf_{ticker}.csv")

    # Balance sheet uncertain predictions
    bal_sheet_uncertain = flag_uncertain_predictions(
        bal_sheet_train,
        bal_sheet_test,
        confidence_threshold=confidence_threshold,
        output_file=f'uncertain_bal_sheet_{ticker}.csv'
    )
    
    # Income/cashflow uncertain predictions
    inc_cf_uncertain = flag_uncertain_predictions(
        income_cashflow_train,
        income_cashflow_test,
        confidence_threshold=confidence_threshold,
        output_file=f'uncertain_inc_cf_{ticker}.csv'
    )

if __name__ == "__main__":
    main()
# Out:
# Company ticker aapl
# Year:  202
# Year must be between 1996 and 2026
# Year:  2025
# Found CIK 0000320193 for ticker aapl
# https://data.sec.gov/submissions/CIK0000320193.json
# DEBUG: 10-K filings for 2025: 1
#   - 2025-10-31: 10-K
# DEBUG: Checking year 2025, found 1 filings
# https://www.sec.gov/Archives/edgar/data/320193/000032019325000079/index.json
# Found filing with required XMLs at: https://www.sec.gov/Archives/edgar/data/320193/000032019325000079/index.json
# {'aapl-20250927_cal.xml': 'https://www.sec.gov/Archives/edgar/data/320193/000032019325000079/aapl-20250927_cal.xml', 'aapl-20250927_def.xml': 'https://www.sec.gov/Archives/edgar/data/320193/000032019325000079/aapl-20250927_def.xml', 'aapl-20250927_htm.xml': 'https://www.sec.gov/Archives/edgar/data/320193/000032019325000079/aapl-20250927_htm.xml', 'aapl-20250927_lab.xml': 'https://www.sec.gov/Archives/edgar/data/320193/000032019325000079/aapl-20250927_lab.xml', 'aapl-20250927_pre.xml': 'https://www.sec.gov/Archives/edgar/data/320193/000032019325000079/aapl-20250927_pre.xml'}
# Downloaded: aapl-20250927_cal.xml
# Downloaded: aapl-20250927_def.xml
# Downloaded: aapl-20250927_htm.xml
# Downloaded: aapl-20250927_lab.xml
# Downloaded: aapl-20250927_pre.xml
# DEBUG: uri_to_prefix has 13 entries
# DEBUG: Found 182 contexts and 7 units
# DEBUG: Found 1131 facts
# NOTE: 15 unmapped facts found. Inspect 'sec_xbrl_facts_aapl.csv' and storage_values['_unmapped_facts']
# Created: sec_xbrl_content_aapl.csv, sec_xbrl_values_aapl.csv, sec_xbrl_contexts_aapl.csv, sec_xbrl_facts_aapl.csv
# ✓ Added to dict_csvs: sec_xbrl_content_aapl.csv
# ✓ Added to dict_csvs: sec_xbrl_values_aapl.csv
# ✓ Added to dict_csvs: sec_xbrl_contexts_aapl.csv
# ✓ Added to dict_csvs: sec_xbrl_facts_aapl.csv
# {'sec_xbrl_content_aapl.csv': '/home/phlka_pug/10K_ETL/sec_xbrl_content_aapl.csv', 'sec_xbrl_values_aapl.csv': '/home/phlka_pug/10K_ETL/sec_xbrl_values_aapl.csv', 'sec_xbrl_contexts_aapl.csv': '/home/phlka_pug/10K_ETL/sec_xbrl_contexts_aapl.csv', 'sec_xbrl_facts_aapl.csv': '/home/phlka_pug/10K_ETL/sec_xbrl_facts_aapl.csv'}
# Columns: ['tag_prefix', 'tag_local', 'gaap_candidate', 'contextRef', 'unitRef', 'decimals', 'value_raw', 'entity_identifier', 'period_start', 'period_end', 'instant']
# Columns: ['tag_prefix', 'tag_local', 'gaap_candidate', 'contextRef', 'unitRef', 'decimals', 'value_raw', 'entity_identifier', 'period_start', 'period_end', 'instant']
# contextRef done
#
# Total metrics in context: 1
# c-57_c-58_c-59_c-60
# [('RevenueRemainingPerformanceObligationPercentage', 1.0)]
#
#
# Total metrics in context: 108
# c-20_c-21_c-22_c-23_c-24_c-25_c-26_c-30_c-31_c-32_c-33_c-37_c-38_c-39_c-40_c-44_c-62_c-63_c-64_c-65_c-66_c-67_c-68_c-69_c-70_c-71_c-72_c-73_c-74_c-75_c-76_c-77_c-78_c-79_c-80_c-81_c-82_c-83_c-84_c-85_c-86_c-87_c-109_c-110_c-111_c-112_c-113_c-114_c-117_c-120_c-121_c-127_c-128_c-134_c-135_c-136_c-137_c-141_c-176_c-177_c-178_c-179_c-180_c-181
# [('OperatingLeaseLiabilityNoncurrent', 20957000000), ('CommercialPaper', 35946000000.0), ('PropertyPlantAndEquipmentGross', 489952000000), ('NoncurrentAssets', 191028000000), ('StockholdersEquity', 487002000000), ('MarketableSecuritiesNoncurrent', 338404000000), ('AvailableForSaleDebtSecuritiesAmortizedCostBasis', 465202000000), ('Cash', 55466000000), ('CashCashEquivalentsRestrictedCashAndRestrictedCashEquivalents', 121591000000), ('LongTermDebtMaturitiesRepaymentsOfPrincipalInYearThree', 9300000000), ('Assets', 724221000000), ('AvailableForSaleDebtSecuritiesAccumulatedGrossUnrealizedGainBeforeTax', 2284000000), ('LesseeOperatingLeaseLiabilityUndiscountedExcessAmount', 2235000000), ('MarketableSecuritiesCurrent', 160502000000), ('LesseeOperatingLeaseLiabilityPaymentsDueYearTwo', 1988000000), ('DebtInstrumentCarryingAmount', 279903000000), ('CashAndCashEquivalentsAtCarryingValue', 136115000000), ('EquitySecuritiesFvNiCurrentAndNoncurrent', 15042000000), ('UnrecordedUnconditionalPurchaseObligationBalanceOnThirdAnniversary', 1981000000), ('DeferredIncomeTaxLiabilities', 14276000000), ('LongTermDebtMaturitiesRepaymentsOfPrincipalInNextTwelveMonths', 12393000000), ('AccountsReceivableNetCurrent', 73187000000), ('LesseeOperatingLeaseLiabilityPaymentsDueAfterYearFive', 5956000000), ('AvailableForSaleSecuritiesDebtSecurities', 452166000000), ('LongTermDebtMaturitiesRepaymentsOfPrincipalAfterYearFive', 49303000000), ('ContractWithCustomerLiabilityCurrent', 17304000000), ('AccumulatedDepreciationDepletionAndAmortizationPropertyPlantAndEquipment', 149462000000), ('DeferredTaxAssetsTaxCreditCarryforwardsForeign', 4700000000), ('OtherAssetsCurrent', 28872000000), ('AccumulatedOtherComprehensiveIncomeLossNetOfTax', -12743000000), ('InventoryNet', 13004000000), ('CommonStockSharesOutstanding', 61383532000), ('UnrecognizedTaxBenefits', 126692000000.0), ('DeferredTaxAssetsDeferredIncome', 6366000000), ('UnrecognizedTaxBenefitsThatWouldImpactEffectiveTaxRate', 21400000000), ('DeferredTaxAssetsLiabilitiesNet', 39182000000), ('RetainedEarningsAccumulatedDeficit', -33418000000), ('LongTermDebtNoncurrent', 164078000000), ('LesseeOperatingLeaseLiabilityPaymentsDueYearFour', 1585000000), ('EquitySecuritiesFvNiCost', 14488000000), ('HedgedLiabilityFairValueHedge', 26100000000), ('LongTermDebtMaturitiesRepaymentsOfPrincipalInYearFive', 4972000000), ('DeferredTaxAssetsNet', 53458000000), ('DeferredTaxLiabilitiesPropertyPlantAndEquipment', 5827000000), ('FinanceLeaseLiabilityPaymentsDue', 1579000000), ('CommonStockParOrStatedValuePerShare', 1e-05), ('AccountsPayableCurrent', 138820000000), ('DeferredTaxLiabilitiesLeasingArrangements', 4425000000), ('ShortTermDebtWeightedAverageInterestRate', 0.09190000000000001), ('DeferredTaxLiabilitiesOther', 1133000000), ('FinanceLeaseLiability', 1230000000), ('FinanceLeaseLiabilityPaymentsDueAfterYearFive', 801000000), ('DeferredTaxAssetsOther', 6390000000), ('LongTermDebtMaturitiesRepaymentsOfPrincipalInYearTwo', 10078000000), ('FinanceLeaseLiabilityPaymentsDueYearTwo', 73000000), ('CommonStockSharesAuthorized', 50400000000), ('AvailableForSaleDebtSecuritiesAccumulatedGrossUnrealizedLossBeforeTax', 15320000000), ('OtherAssetsNoncurrent', 158561000000), ('LiabilitiesAndStockholdersEquity', 724221000000), ('CommitmentsAndContingencies', nan), ('DeferredTaxAssetsTaxCreditCarryforwards', 17499000000), ('AssetsCurrent', 300944000000), ('PropertyPlantAndEquipmentNet', 95514000000), ('FinanceLeaseLiabilityUndiscountedExcessAmount', 349000000), ('UnrecordedUnconditionalPurchaseObligationBalanceOnFirstAnniversary', 4752000000), ('LongTermDebtFairValue', 168800000000), ('LongTermDebtCurrent', 23262000000), ('LesseeOperatingLeaseLiabilityPaymentsDueNextTwelveMonths', 1967000000), ('Liabilities', 593538000000), ('OtherLiabilitiesNoncurrent', 87437000000), ('FinanceLeaseLiabilityPaymentsDueYearThree', 51000000), ('OtherLiabilitiesCurrent', 144691000000), ('DeferredTaxAssetsGross', 73290000000), ('FinanceLeaseLiabilityNoncurrent' ...
#
#
# Total metrics in context: 101
# c-12_c-13_c-14_c-15_c-16_c-17_c-1_c-18_c-19_c-34_c-35_c-36_c-41_c-42_c-43_c-45_c-46_c-47_c-48_c-49_c-50_c-51_c-52_c-53_c-54_c-55_c-56_c-116_c-138_c-139_c-140_c-145_c-147_c-148_c-149_c-150_c-151_c-152_c-153_c-154_c-155_c-156_c-157_c-158_c-159_c-160_c-161_c-162_c-163_c-164_c-165_c-166_c-167_c-168_c-169_c-170_c-171_c-172_c-173_c-174_c-175_c-27_c-28_c-29
# [('CashCashEquivalentsRestrictedCashAndRestrictedCashEquivalentsPeriodIncreaseDecreaseIncludingExchangeRateEffect', 10957000000), ('AllocatedShareBasedCompensationExpense', 35384000000), ('RevenueFromContractWithCustomerExcludingAssessedTax', 5457990000000), ('EarningsPerShareDiluted', 19.669999999999998), ('EarningsPerShareBasic', 19.759999999999998), ('ProceedsFromRepaymentsOfCommercialPaper', -2050000000), ('NetCashProvidedByUsedInInvestingActivities', 21835000000), ('NetCashProvidedByUsedInOperatingActivities', 340279000000), ('WeightedAverageNumberOfDilutedSharesOutstanding', 46225339000), ('ProceedsFromMaturitiesPrepaymentsAndCallsOfAvailableForSaleSecurities', 131804000000), ('CostOfGoodsAndServicesSold', 1936347000000), ('StateAndLocalIncomeTaxExpenseBenefitContinuingOperations', 4490000000), ('OtherComprehensiveIncomeLossForeignCurrencyTransactionAndTranslationAdjustmentNetOfTax', -637000000), ('AdjustmentsRelatedToTaxWithholdingForShareBasedCompensation', 17332000000), ('IncomeLossFromContinuingOperationsBeforeIncomeTaxesExtraordinaryItemsNoncontrollingInterest', 369950000000), ('CommonStockDividendsPerShareDeclared', 2.94), ('SellingGeneralAndAdministrativeExpense', 78630000000), ('DeferredStateAndLocalIncomeTaxExpenseBenefit', -486000000), ('SellingAndMarketingExpense', 112846000000), ('CurrentIncomeTaxExpenseBenefit', 10200000000), ('StockRepurchasedAndRetiredDuringPeriodShares', 1774463000), ('ShareBasedCompensationArrangementByShareBasedPaymentAwardEquityInstrumentsOtherThanOptionsVestedInPeriod', 76845000), ('PaymentsRelatedToTaxWithholdingForShareBasedCompensation', 28532000000), ('IncomeTaxExpenseBenefit', 67209000000), ('ContractWithCustomerLiabilityRevenueRecognized', 24126000000), ('CurrentStateAndLocalTaxExpenseBenefit', 4976000000), ('CurrentFederalTaxExpenseBenefit', 21703000000), ('ShareBasedCompensationArrangementByShareBasedPaymentAwardEquityInstrumentsOtherThanOptionsVestedInPeriodTotalFairValue', 48800000000), ('GeneralAndAdministrativeExpense', 22207000000), ('PaymentsForRepurchaseOfCommonStock', 263210000000), ('StockRepurchasedAndRetiredDuringPeriodValue', 352244000000), ('IncomeTaxReconciliationTaxCreditsResearch', 3658000000), ('ProceedsFromShortTermDebtMaturingInMoreThanThreeMonths', 5836000000), ('OperatingIncomeLoss', 741134000000), ('ProceedsFromRepaymentsOfShortTermDebtMaturingInMoreThanThreeMonths', 1143000000), ('ShareBasedCompensation', 35384000000), ('OtherNoncashIncomeExpense', 4582000000), ('OtherComprehensiveIncomeLossNetOfTaxPortionAttributableToParent', 5538000000), ('PaymentsOfDividends', 45680000000), ('IncomeTaxReconciliationForeignIncomeTaxRateDifferential', -19175000000), ('IncreaseDecreaseInAccountsReceivable', 12158000000), ('IncreaseDecreaseInAccountsPayable', 5033000000), ('UnrecognizedTaxBenefitsIncreasesResultingFromPriorPeriodTaxPositions', 5742000000), ('ShareBasedCompensationArrangementByShareBasedPaymentAwardEquityInstrumentsOtherThanOptionsGrantsInPeriod', 73466000), ('GrossProfit', 545032000000), ('DepreciationDepletionAndAmortization', 34662000000), ('IncomeLossFromContinuingOperationsBeforeIncomeTaxesForeign', 232200000000.0), ('Depreciation', 24700000000.0), ('OperatingExpenses', 174465000000), ('PaymentsToAcquireAvailableForSaleSecuritiesDebt', 102576000000), ('ForeignIncomeTaxExpenseBenefitContinuingOperations', 44744000000), ('NetCashProvidedByUsedInFinancingActivities', -351157000000), ('UnrecognizedTaxBenefitsDecreasesResultingFromSettlementsWithTaxingAuthorities', 4851000000), ('IncomeTaxesPaidNet', 88150000000), ('ShareBasedCompensationArrangementByShareBasedPaymentAwardEquityInstrumentsOtherThanOptionsForfeituresWeightedAverageGrantDateFairValue', 183.03), ('UnrecognizedTaxBenefitsDecreasesResultingFromPriorPeriodTaxPositions', 1920000000), ('OtherComprehensiveIncomeLossAvailableForSaleSecuritiesAdjustmentNetOfTax', 9101000000), ('ProceedsFromIssuanceOfLongTermDebt', 9709000000), ('FederalIncomeTaxExpenseBenefitContinuingOperations', 17975000000), ('Di ...
#
#
# Total metrics in context: 1
# c-61
# [('AntidilutiveSecuritiesExcludedFromComputationOfEarningsPerShareAmount', 24000000)]
#
#
# Total metrics in context: 2
# c-88
# [('RestrictedCashAndCashEquivalents', 2600000000), ('DebtSecuritiesAvailableForSaleRestricted', 13200000000)]
#
#
# Total metrics in context: 0
#
# Total metrics in context: 1
# c-93_c-94_c-95_c-96_c-97_c-98
# [('DerivativeNotionalAmount', 354738000000)]
#
#
# Total metrics in context: 1
# c-100_c-101_c-102_c-104_c-105_c-107_c-108
# [('ConcentrationRiskPercentage1', 1.97)]
#
#
# Total metrics in context: 0
#
# Total metrics in context: 2
# c-124_c-125_c-129_c-130_c-131_c-132
# [('DebtInstrumentInterestRateStatedPercentage', 0.136), ('DebtInstrumentInterestRateEffectivePercentage', 0.2133)]
#
#
# Total metrics in context: 0
#
# Total metrics in context: 1
# c-143
# [('ShareBasedCompensationArrangementByShareBasedPaymentAwardNumberOfSharesAuthorized', 1300000000)]
#
#
# Total metrics in context: 3
# c-144_c-146
# [('ShareBasedCompensationArrangementByShareBasedPaymentAwardEquityInstrumentsOtherThanOptionsNonvestedNumber', 314900000), ('ShareBasedCompensationArrangementByShareBasedPaymentAwardEquityInstrumentsOtherThanOptionsNonvestedWeightedAverageGrantDateFairValue', 348.48), ('EmployeeServiceShareBasedCompensationNonvestedAwardsTotalCompensationCostNotYetRecognized', 21800000000)]
#
# ✓ Created and exported to: aapl_data.csv
# ✓ Appended to: bal_sheet_aapl_data.csv
# ✓ Created and exported to: inc_cf_aapl_data.csv
# ✓ Appended to: aapl_data.csv
# ✓ Appended to: aapl_data.csv
# ✓ Appended to: aapl_data.csv
# ✓ Appended to: aapl_data.csv
# ✓ Appended to: aapl_data.csv
# ✓ Appended to: aapl_data.csv
# ✓ Appended to: aapl_data.csv
# Confidence threshold (0.0-1.0):  0.4
# /home/phlka_pug/anaconda3/envs/myenv/lib/python3.13/site-packages/sklearn/feature_extraction/text.py:526: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# LogisticRegression: train=0.8734, val=0.6000
# MultinomialNB: train=0.8481, val=0.4857
# DecisionTreeClassifier: train=0.7848, val=0.2857
# /home/phlka_pug/anaconda3/envs/myenv/lib/python3.13/site-packages/sklearn/feature_extraction/text.py:526: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# LogisticRegression: train=0.9848, val=0.8276
# /home/phlka_pug/anaconda3/envs/myenv/lib/python3.13/site-packages/sklearn/feature_extraction/text.py:526: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# LogisticRegression: train=0.8939, val=0.4483
# MultinomialNB: train=0.7576, val=0.4138
# DecisionTreeClassifier: train=0.6061, val=0.4483
# Income statement: 78 rows in nlp_inc_aapl.csv
# Cashflow statement: 23 rows in nlp_cf_aapl.csv
#
# ⚠ Found 176 uncertain predictions (threshold: 0.4):
#   Require manual review and annotation.
#
#                                                                                     label             value               category  prediction_confidence
#                                                        DerivativeFairValueOfDerivativeNet      -719,000,000   subtotal liabilities               0.174233
#                                                                                      Cash    55,466,000,000         current assets               0.182184
#                                                             HedgedLiabilityFairValueHedge    26,100,000,000    current liabilities               0.189065
#                                                               CommitmentsAndContingencies               NaN      noncurrent assets               0.193358
#                                                               CommitmentsAndContingencies               NaN      noncurrent assets               0.193358
#                                                  ShortTermDebtWeightedAverageInterestRate                 0      noncurrent assets               0.194457
#                                                  ShortTermDebtWeightedAverageInterestRate                 0      noncurrent assets               0.194457
#                                            DeferredTaxLiabilitiesOtherComprehensiveIncome       712,000,000                 equity               0.205935
#                                                 DeferredTaxLiabilitiesLeasingArrangements     1,862,000,000    current liabilities               0.206223
#                                                 DeferredTaxLiabilitiesLeasingArrangements     4,425,000,000    current liabilities               0.206223
#                                                          LiabilitiesAndStockholdersEquity   724,221,000,000                 equity               0.208554
#                                                          LiabilitiesAndStockholdersEquity   662,404,000,000                 equity               0.208554
#                                                   StockRepurchaseProgramAuthorizedAmount1   225,000,000,000                 equity               0.211958
#                                                            StandardProductWarrantyAccrual    14,450,000,000      noncurrent assets               0.212711
#                                             DebtInstrumentInterestRateEffectivePercentage                 0      noncurrent assets               0.217242
#                                                           DeferredTaxAssetsLiabilitiesNet    16,202,000,000      noncurrent assets               0.217717
#                                                           DeferredTaxAssetsLiabilitiesNet    39,182,000,000      noncurrent assets               0.217717
#                                                               DeferredTaxLiabilitiesOther     1,305,000,000    current liabilities               0.218751
#                                                               DeferredTaxLiabilitiesOther     1,133,000,000    current liabilities               0.218751
#                                                DebtInstrumentInterestRateStatedPercentage                 0      noncurrent assets               0.221463
# EmployeeServiceShareBasedCompensationNonvestedAwardsTotalCompensationCostNotYetRecognized    12,200,000,000      noncurrent assets               0.226045
#                                                              DeferredIncomeTaxLiabilities    14,276,000,000      noncurrent assets               0.228487
#                                                              DeferredIncomeTaxLiabilities    21,733,000,000      noncurrent assets               0.228487
#                                    LongTermDebtMaturitiesRepaymentsOfPrincipalInYearThree    11,389,000,000      noncurrent assets               0.229915
#                                    LongTermDebtMaturitiesRepaymentsOfPrincipalInYearThree     9,300,000,000      noncurrent assets               0.229915
#                                                                              InventoryNet    13,004,000,000      noncurrent assets               0.232168
#                                                                              InventoryNet     8,167,000,000      noncurrent assets               0.232168
#                                                      DerivativeFairValueOfDerivativeAsset     8,588,000,000        subtotal assets               0.232750
#                                      LongTermDebtMaturitiesRepaymentsOfPrincipalInYearTwo    10,078,000,000      noncurrent assets               0.233998
#                                      LongTermDebtMaturitiesRepaymentsOfPrincipalInYearTwo     9,569,000,000      noncurrent assets               0.233998
#                                     LongTermDebtMaturitiesRepaymentsOfPrincipalInYearFour     5,235,000,000      noncurrent assets               0.234270
#                                     LongTermDebtMaturitiesRepaymentsOfPrincipalInYearFour    10,115,000,000      noncurrent assets               0.234270
#                                     LongTermDebtMaturitiesRepaymentsOfPrincipalInYearFive    10,914,000,000      noncurrent assets               0.240998
#                                     LongTermDebtMaturitiesRepaymentsOfPrincipalInYearFive     4,972,000,000      noncurrent assets               0.240998
#                                           DeferredTaxAssetsTaxCreditCarryforwardsResearch     4,000,000,000      noncurrent assets               0.244283
#                                            DeferredTaxAssetsTaxCreditCarryforwardsForeign     4,700,000,000      noncurrent assets               0.245798
#                                                   DeferredTaxAssetsTaxCreditCarryforwards    17,499,000,000      noncurrent assets               0.246944
#                                  LongTermDebtMaturitiesRepaymentsOfPrincipalAfterYearFive    49,303,000,000      noncurrent assets               0.247597
#                                  LongTermDebtMaturitiesRepaymentsOfPrincipalAfterYearFive    55,341,000,000      noncurrent assets               0.247597
#                                                                                    Assets   662,404,000,000      noncurrent assets               0.251614
#                                                                                    Assets   724,221,000,000      noncurrent assets               0.251614
#                                                                NontradeReceivablesCurrent    44,203,000,000    current liabilities               0.253949
#                                                                NontradeReceivablesCurrent    66,013,000,000    current liabilities               0.253949
#                                                                              LongTermDebt   187,340,000,000 noncurrent liabilities               0.255835
#                                    DeferredTaxAssetsTaxDeferredExpenseReservesAndAccruals    10,130,000,000      noncurrent assets               0.256056
#                                    DeferredTaxAssetsTaxDeferredExpenseReservesAndAccruals    12,268,000,000      noncurrent assets               0.256056
#                                                               MarketableSecuritiesCurrent   209,280,000,000         current assets               0.257043
#                                                               MarketableSecuritiesCurrent   160,502,000,000         current assets               0.257043
#                                UnrecordedUnconditionalPurchaseObligationDueAfterFiveYears       130,000,000    current liabilities               0.261125
#                                UnrecordedUnconditionalPurchaseObligationDueAfterFiveYears       773,000,000    current liabilities               0.261125
#                                                                   OperatingLeaseLiability    12,490,000,000   subtotal liabilities               0.261172
#                                                                   OperatingLeaseLiability     9,181,000,000   subtotal liabilities               0.261172
#                                                                               Liabilities   506,577,000,000    current liabilities               0.263018
#                                                                               Liabilities   593,538,000,000    current liabilities               0.263018
#                             LongTermDebtMaturitiesRepaymentsOfPrincipalInNextTwelveMonths     8,750,000,000    current liabilities               0.263335
#                             LongTermDebtMaturitiesRepaymentsOfPrincipalInNextTwelveMonths    12,393,000,000    current liabilities               0.263335
#                                                              DebtInstrumentCarryingAmount   279,903,000,000 noncurrent liabilities               0.263397
#                                                              DebtInstrumentCarryingAmount   521,614,000,000 noncurrent liabilities               0.263397
#                                                                    DeferredTaxAssetsGross    73,290,000,000      noncurrent assets               0.265968
#                                                                    DeferredTaxAssetsGross    39,723,000,000      noncurrent assets               0.265968
#                                           DeferredTaxLiabilitiesPropertyPlantAndEquipment     5,827,000,000      noncurrent assets               0.266368
#                                                                     FinanceLeaseLiability     1,230,000,000    current liabilities               0.267477
#                                                                     FinanceLeaseLiability       661,000,000    current liabilities               0.267477
#                                                         OtherAccruedLiabilitiesNoncurrent    47,278,000,000    current liabilities               0.270275
#                                                                    DeferredTaxAssetsOther     4,583,000,000      noncurrent assets               0.270513
#                                                                    DeferredTaxAssetsOther     6,390,000,000      noncurrent assets               0.270513
#                                           AccumulatedOtherComprehensiveIncomeLossNetOfTax      -990,000,000                 equity               0.272258
#                                           AccumulatedOtherComprehensiveIncomeLossNetOfTax   -12,743,000,000                 equity               0.272258
#                                                       DeferredTaxAssetsValuationAllowance     1,788,000,000      noncurrent assets               0.273296
#                                                       DeferredTaxAssetsValuationAllowance    19,832,000,000      noncurrent assets               0.273296
#                                                        RetainedEarningsAccumulatedDeficit   -33,418,000,000                 equity               0.275606
#                                                        RetainedEarningsAccumulatedDeficit    60,864,000,000                 equity               0.275606
#                                                                     LiabilitiesNoncurrent   251,515,000,000 noncurrent liabilities               0.278149
#                                                                     LiabilitiesNoncurrent   295,467,000,000 noncurrent liabilities               0.278149
#                                                           DeferredTaxAssetsDeferredIncome     6,366,000,000      noncurrent assets               0.278884
#                                                           DeferredTaxAssetsDeferredIncome     3,010,000,000      noncurrent assets               0.278884
#                                                                     RestrictedInvestments    37,500,000,000      noncurrent assets               0.280253
#                                                  EquitySecuritiesFvNiCurrentAndNoncurrent    15,042,000,000         current assets               0.282760
#                                                  DerivativeFairValueOfDerivativeLiability     7,199,000,000   subtotal liabilities               0.283079
#                                                              AccruedIncomeTaxesNoncurrent    57,715,000,000 noncurrent liabilities               0.284268
#                               UnrecordedUnconditionalPurchaseObligationBalanceSheetAmount    13,831,000,000    current liabilities               0.285035
#                               UnrecordedUnconditionalPurchaseObligationBalanceSheetAmount     8,652,000,000    current liabilities               0.285035
#                       UnrecordedUnconditionalPurchaseObligationBalanceOnSecondAnniversary     3,708,000,000    current liabilities               0.286205
#                       UnrecordedUnconditionalPurchaseObligationBalanceOnSecondAnniversary     2,885,000,000    current liabilities               0.286205
#                               UnrecognizedTaxBenefitsIncomeTaxPenaltiesAndInterestAccrued     2,700,000,000 noncurrent liabilities               0.286466
#                                                                        StockholdersEquity   792,188,000,000                 equity               0.288110
#                                                                        StockholdersEquity   487,002,000,000                 equity               0.288110
#                                                                     LongTermDebtFairValue   168,800,000,000 noncurrent liabilities               0.288615
#                                                                     LongTermDebtFairValue   224,600,000,000 noncurrent liabilities               0.288615
#                       UnrecordedUnconditionalPurchaseObligationBalanceOnFourthAnniversary       357,000,000    current liabilities               0.290213
#                       UnrecordedUnconditionalPurchaseObligationBalanceOnFourthAnniversary     1,306,000,000    current liabilities               0.290213
#                        UnrecordedUnconditionalPurchaseObligationBalanceOnFirstAnniversary     3,476,000,000    current liabilities               0.292853
#                        UnrecordedUnconditionalPurchaseObligationBalanceOnFirstAnniversary     4,752,000,000    current liabilities               0.292853
#                        UnrecordedUnconditionalPurchaseObligationBalanceOnThirdAnniversary     1,981,000,000    current liabilities               0.293081
#                        UnrecordedUnconditionalPurchaseObligationBalanceOnThirdAnniversary     1,700,000,000    current liabilities               0.293081
#                        UnrecordedUnconditionalPurchaseObligationBalanceOnFifthAnniversary       104,000,000    current liabilities               0.294556
#                        UnrecordedUnconditionalPurchaseObligationBalanceOnFifthAnniversary       788,000,000    current liabilities               0.294556
#                                                RestrictedCashAndCashEquivalentsNoncurrent     3,094,000,000         current assets               0.295974
#                                                                      DeferredTaxAssetsNet    53,458,000,000      noncurrent assets               0.298192
#                                                                      DeferredTaxAssetsNet    37,935,000,000      noncurrent assets               0.298192
#                                                              AccountsReceivableNetCurrent    39,046,000,000         current assets               0.300898
#                                                              AccountsReceivableNetCurrent    73,187,000,000         current assets               0.300898
#                                                                OtherLiabilitiesNoncurrent    87,437,000,000 noncurrent liabilities               0.301514
#                                                                OtherLiabilitiesNoncurrent   104,993,000,000 noncurrent liabilities               0.301514
#                                                                        OtherAssetsCurrent    28,872,000,000         current assets               0.306228
#                                                                        OtherAssetsCurrent    23,616,000,000         current assets               0.306228
#                                             FinanceLeaseLiabilityUndiscountedExcessAmount       429,000,000   subtotal liabilities               0.307196
#                                             FinanceLeaseLiabilityUndiscountedExcessAmount       349,000,000   subtotal liabilities               0.307196
#                                                             OperatingLeaseRightOfUseAsset     8,570,000,000      noncurrent assets               0.309156
#                                                             OperatingLeaseRightOfUseAsset    21,439,000,000      noncurrent assets               0.309156
#                                                            PropertyPlantAndEquipmentGross   398,966,000,000      noncurrent assets               0.309396
#                                                            PropertyPlantAndEquipmentGross   489,952,000,000      noncurrent assets               0.309396
#                                                              PropertyPlantAndEquipmentNet    95,514,000,000      noncurrent assets               0.313351
#                                                              PropertyPlantAndEquipmentNet    74,144,000,000      noncurrent assets               0.313351
#                                     DecreaseInUnrecognizedTaxBenefitsIsReasonablyPossible     3,900,000,000 noncurrent liabilities               0.315352
#                                     DecreaseInUnrecognizedTaxBenefitsIsReasonablyPossible     6,000,000,000 noncurrent liabilities               0.315352
#                                                        OtherAssetsMiscellaneousNoncurrent   118,285,000,000      noncurrent assets               0.316044
#                                                          FinanceLeaseLiabilityPaymentsDue     1,579,000,000    current liabilities               0.316280
#                                                          FinanceLeaseLiabilityPaymentsDue     1,090,000,000    current liabilities               0.316280
#                                             FinanceLeaseLiabilityPaymentsDueAfterYearFive       895,000,000 noncurrent liabilities               0.317298
#                                             FinanceLeaseLiabilityPaymentsDueAfterYearFive       801,000,000 noncurrent liabilities               0.317298
#                                                                       LongTermDebtCurrent    23,262,000,000    current liabilities               0.317735
#                                                                       LongTermDebtCurrent    19,033,000,000    current liabilities               0.317735
#                                                                             AssetsCurrent   306,532,000,000         current assets               0.318939
#                                                                             AssetsCurrent   300,944,000,000         current assets               0.318939
#                                                     CashAndCashEquivalentsAtCarryingValue   136,115,000,000         current assets               0.326259
#                                                     CashAndCashEquivalentsAtCarryingValue   212,535,000,000         current assets               0.326259
#                                              CommonStocksIncludingAdditionalPaidInCapital   176,844,000,000                 equity               0.328251
#                                              CommonStocksIncludingAdditionalPaidInCapital    95,953,000,000                 equity               0.328251
#                                                  AvailableForSaleSecuritiesDebtSecurities 1,145,139,000,000      noncurrent assets               0.328841
#                                                  AvailableForSaleSecuritiesDebtSecurities   452,166,000,000      noncurrent assets               0.328841
#                                                                          AssetsNoncurrent   423,277,000,000      noncurrent assets               0.329461
#                                                                          AssetsNoncurrent   355,872,000,000      noncurrent assets               0.329461
#                                                                           CommercialPaper    35,946,000,000    current liabilities               0.334888
#                                                                           CommercialPaper    21,976,000,000    current liabilities               0.334888
#                                           RestrictedCashAndCashEquivalentsAtCarryingValue        59,000,000         current assets               0.336835
#                                                  LesseeOperatingLeaseLiabilityPaymentsDue    14,725,000,000 noncurrent liabilities               0.337067
#                                                  LesseeOperatingLeaseLiabilityPaymentsDue    10,144,000,000 noncurrent liabilities               0.337067
#                                                                  EquitySecuritiesFvNiCost    14,488,000,000         current assets               0.340560
#                                                                DeferredIncomeTaxAssetsNet    40,276,000,000      noncurrent assets               0.343490
#                                    UnrecognizedTaxBenefitsThatWouldImpactEffectiveTaxRate    21,400,000,000 noncurrent liabilities               0.344703
#                                    UnrecognizedTaxBenefitsThatWouldImpactEffectiveTaxRate    17,400,000,000 noncurrent liabilities               0.344703
#                                                                   UnrecognizedTaxBenefits    82,295,000,000 noncurrent liabilities               0.344804
#                                                                   UnrecognizedTaxBenefits   126,692,000,000 noncurrent liabilities               0.344804
#                                          AvailableForSaleDebtSecuritiesAmortizedCostBasis   465,202,000,000      noncurrent assets               0.345739
#                                          AvailableForSaleDebtSecuritiesAmortizedCostBasis 1,135,179,000,000      noncurrent assets               0.345739
#                                                                 AccruedIncomeTaxesCurrent    39,617,000,000    current liabilities               0.346726
#                                                             ContractWithCustomerLiability    18,300,000,000    current liabilities               0.347954
#                                                             ContractWithCustomerLiability    26,500,000,000    current liabilities               0.347954
#                                     LesseeOperatingLeaseLiabilityPaymentsDueAfterYearFive     3,845,000,000 noncurrent liabilities               0.348041
#                                     LesseeOperatingLeaseLiabilityPaymentsDueAfterYearFive     5,956,000,000 noncurrent liabilities               0.348041
#                             CashCashEquivalentsRestrictedCashAndRestrictedCashEquivalents   121,591,000,000         current assets               0.348092
#                             CashCashEquivalentsRestrictedCashAndRestrictedCashEquivalents   136,215,000,000         current assets               0.348092
#                                                            MarketableSecuritiesNoncurrent   338,404,000,000      noncurrent assets               0.349381
#                                                            MarketableSecuritiesNoncurrent   412,456,000,000      noncurrent assets               0.349381
#                                                                    LongTermDebtNoncurrent   190,474,000,000 noncurrent liabilities               0.349611
#                                                                    LongTermDebtNoncurrent   164,078,000,000 noncurrent liabilities               0.349611
#                                     LesseeOperatingLeaseLiabilityUndiscountedExcessAmount       963,000,000   subtotal liabilities               0.350280
#                                     LesseeOperatingLeaseLiabilityUndiscountedExcessAmount     2,235,000,000   subtotal liabilities               0.350280
#                                              DeferredTaxAssetsGoodwillAndIntangibleAssets    19,962,000,000      noncurrent assets               0.351801
#                     AvailableForSaleDebtSecuritiesAccumulatedGrossUnrealizedGainBeforeTax     7,964,000,000      noncurrent assets               0.354276
#                     AvailableForSaleDebtSecuritiesAccumulatedGrossUnrealizedGainBeforeTax     2,284,000,000      noncurrent assets               0.354276
#                           DebtInstrumentUnamortizedDiscountPremiumAndDebtIssuanceCostsNet       538,000,000      noncurrent assets               0.357622
#                           DebtInstrumentUnamortizedDiscountPremiumAndDebtIssuanceCostsNet       630,000,000      noncurrent assets               0.357622
#                     AvailableForSaleDebtSecuritiesAccumulatedGrossUnrealizedLossBeforeTax     1,332,000,000      noncurrent assets               0.363953
#                     AvailableForSaleDebtSecuritiesAccumulatedGrossUnrealizedLossBeforeTax    15,320,000,000      noncurrent assets               0.363953
#                                                                     OtherAssetsNoncurrent   158,561,000,000      noncurrent assets               0.364517
#                                                                     OtherAssetsNoncurrent    75,500,000,000      noncurrent assets               0.364517
#                                                                    AccountsPayableCurrent   138,820,000,000    current liabilities               0.367095
#                                                                    AccountsPayableCurrent    88,532,000,000    current liabilities               0.367095
#                                                                          NoncurrentAssets   191,028,000,000      noncurrent assets               0.372126
#                                                                          NoncurrentAssets   148,288,000,000      noncurrent assets               0.372126
#                                  LesseeOperatingLeaseLiabilityPaymentsDueNextTwelveMonths     1,967,000,000    current liabilities               0.383670
#                                  LesseeOperatingLeaseLiabilityPaymentsDueNextTwelveMonths     1,493,000,000    current liabilities               0.383670
#                                                           FinanceLeaseLiabilityNoncurrent     1,444,000,000 noncurrent liabilities               0.397991
#                                                           FinanceLeaseLiabilityNoncurrent       637,000,000 noncurrent liabilities               0.397991
#
# ✓ Uncertain predictions saved to: uncertain_bal_sheet_aapl.csv
#   Please review and manually annotate these predictions.
#
# ⚠ Found 90 uncertain predictions (threshold: 0.4):
#   Require manual review and annotation.
#
#                                                                                                                                     label             value statement  statement_confidence              category  category_confidence
#                                                                                                      CommonStockDividendsPerShareDeclared                 2    income              0.682135  financing activities             0.115444
#                                                                                                    DeferredForeignIncomeTaxExpenseBenefit     1,620,000,000    income              0.725384    Operating Expenses             0.115866
#                                                                                                EffectiveIncomeTaxRateContinuingOperations                 0    income              0.727446  comprehensive income             0.116128
#                                               IncomeLossFromContinuingOperationsBeforeIncomeTaxesExtraordinaryItemsNoncontrollingInterest   369,950,000,000    income              0.747258  comprehensive income             0.116522
#                                                                                       RevenueFromContractWithCustomerExcludingAssessedTax 5,457,990,000,000    income              0.674781  operating activities             0.116823
#                                                                                        ForeignIncomeTaxExpenseBenefitContinuingOperations    44,744,000,000    income              0.743614    Operating Expenses             0.117236
#                                                             IncomeTaxReconciliationIncomeTaxExpenseBenefitAtFederalStatutoryIncomeTaxRate    77,690,000,000    income              0.732445  comprehensive income             0.117491
#                                                                                                            CurrentIncomeTaxExpenseBenefit    10,200,000,000    income              0.735811    Operating Expenses             0.117512
#                                                                                                    DeferredFederalIncomeTaxExpenseBenefit    -8,528,000,000    income              0.725444    Operating Expenses             0.119255
#                                                                                              DeferredStateAndLocalIncomeTaxExpenseBenefit      -486,000,000    income              0.722692    Operating Expenses             0.119564
#                                                                                  StateAndLocalIncomeTaxExpenseBenefitContinuingOperations     4,490,000,000    income              0.740617    Operating Expenses             0.119790
#                                                                                        FederalIncomeTaxExpenseBenefitContinuingOperations    17,975,000,000    income              0.743441    Operating Expenses             0.119862
#                                                                                                                               GrossProfit   545,032,000,000    income              0.613603  comprehensive income             0.120764
#                                                                                                                CostOfGoodsAndServicesSold 1,936,347,000,000    income              0.638798    Operating Expenses             0.121812
#                                                                                            ContractWithCustomerLiabilityRevenueRecognized    24,126,000,000    income              0.673990               Revenue             0.121882
#                                                                                                                   IncomeTaxExpenseBenefit    67,209,000,000    income              0.728716    Operating Expenses             0.122046
#                                                                                                 IncomeTaxReconciliationTaxCreditsResearch     3,658,000,000    income              0.687234  comprehensive income             0.124610
#                                                             UnrecognizedTaxBenefitsDecreasesResultingFromSettlementsWithTaxingAuthorities     4,851,000,000    income              0.591181  operating activities             0.124771
#                                                                                                                        IncomeTaxesPaidNet    88,150,000,000    income              0.666916  comprehensive income             0.125260
#                                                                      UnrecognizedTaxBenefitsDecreasesResultingFromPriorPeriodTaxPositions     1,920,000,000    income              0.600097  comprehensive income             0.125680
#                                                                                                           CurrentForeignTaxExpenseBenefit    58,924,000,000    income              0.715767    Operating Expenses             0.126297
#                                                                      UnrecognizedTaxBenefitsIncreasesResultingFromPriorPeriodTaxPositions     5,742,000,000    income              0.610189  comprehensive income             0.127926
#                                                       UnrecognizedTaxBenefitsReductionsResultingFromLapseOfApplicableStatuteOfLimitations     2,275,000,000    income              0.655738  comprehensive income             0.128938
#                            CashCashEquivalentsRestrictedCashAndRestrictedCashEquivalentsPeriodIncreaseDecreaseIncludingExchangeRateEffect    10,957,000,000  cashflow              0.631703  operating activities             0.129423
#                                                                                                     CurrentStateAndLocalTaxExpenseBenefit     4,976,000,000    income              0.706197    Operating Expenses             0.130499
#                                                                                                           CurrentFederalTaxExpenseBenefit    21,703,000,000    income              0.709602    Operating Expenses             0.130992
#                                                                        IncomeTaxReconciliationChangeInDeferredTaxAssetsValuationAllowance     2,091,000,000    income              0.649422  comprehensive income             0.132557
#                                                                       EffectiveIncomeTaxRateReconciliationAtFederalStatutoryIncomeTaxRate                 0    income              0.705866  comprehensive income             0.132633
#                                                                                IncomeLossFromContinuingOperationsBeforeIncomeTaxesForeign   232,200,000,000    income              0.737590  comprehensive income             0.132792
#                                                                                   IncomeTaxReconciliationForeignIncomeTaxRateDifferential   -19,175,000,000    income              0.700912  comprehensive income             0.133823
#                                                                                           PaymentsToAcquireAvailableForSaleSecuritiesDebt   102,576,000,000    income              0.562396  comprehensive income             0.137154
#                                                                                    ProceedsFromShortTermDebtMaturingInMoreThanThreeMonths     5,836,000,000  cashflow              0.505126  financing activities             0.137855
#                                                                                                                       OperatingIncomeLoss   741,134,000,000    income              0.775454 nonoperating expenses             0.139756
#                                                                                          ProceedsFromSaleOfAvailableForSaleSecuritiesDebt    29,853,000,000    income              0.613360  comprehensive income             0.141084
#                                                                     ProceedsFromMaturitiesPrepaymentsAndCallsOfAvailableForSaleSecurities   131,804,000,000    income              0.573784  comprehensive income             0.141568
#                                                                                                                                 Dividends    45,627,000,000    income              0.566284  financing activities             0.141752
#                                                                    UnrecognizedTaxBenefitsIncreasesResultingFromCurrentPeriodTaxPositions     8,965,000,000    income              0.636402  comprehensive income             0.143697
#                                                                                                     StockIssuedDuringPeriodValueNewIssues     4,267,000,000    income              0.535542  financing activities             0.149598
#                                                                                    RepaymentsOfShortTermDebtMaturingInMoreThanThreeMonths     4,693,000,000    income              0.529763  financing activities             0.150914
#                                                                                                   IncomeTaxReconciliationOtherAdjustments       501,000,000    income              0.644738  comprehensive income             0.157940
#                                                                                                NetCashProvidedByUsedInInvestingActivities    21,835,000,000  cashflow              0.622842  investing activities             0.160422
#                                                                                                                     EarningsPerShareBasic                19    income              0.724537    earnings per share             0.166760
#                                                                                                                             NetIncomeLoss   302,741,000,000    income              0.774507            net income             0.166921
#                                                                                                                   EarningsPerShareDiluted                19    income              0.720150    earnings per share             0.172239
#                                                                                             WeightedAverageNumberOfSharesOutstandingBasic    46,036,514,000    income              0.725188    earnings per share             0.173952
#                                                                                                        ProceedsFromIssuanceOfLongTermDebt     9,709,000,000  cashflow              0.523749  financing activities             0.175517
# ShareBasedCompensationArrangementByShareBasedPaymentAwardEquityInstrumentsOtherThanOptionsGrantsInPeriodWeightedAverageGrantDateFairValue               551    income              0.629006    Operating Expenses             0.176309
#                                                                                           WeightedAverageNumberOfDilutedSharesOutstanding    46,225,339,000    income              0.721699    earnings per share             0.176421
# ShareBasedCompensationArrangementByShareBasedPaymentAwardEquityInstrumentsOtherThanOptionsVestedInPeriodWeightedAverageGrantDateFairValue               159    income              0.628396    Operating Expenses             0.177349
#                                                                                                                  RepaymentsOfLongTermDebt    32,041,000,000    income              0.517265  financing activities             0.177730
#                                                                        ProceedsFromRepaymentsOfShortTermDebtMaturingInMoreThanThreeMonths     1,143,000,000  cashflow              0.543749  financing activities             0.178447
#                                                                        IncrementalCommonSharesAttributableToShareBasedPaymentArrangements       188,825,000    income              0.524675           disclosures             0.180119
#    ShareBasedCompensationArrangementByShareBasedPaymentAwardEquityInstrumentsOtherThanOptionsForfeituresWeightedAverageGrantDateFairValue               183    income              0.641275    Operating Expenses             0.180311
#                                                                                                NetCashProvidedByUsedInOperatingActivities   340,279,000,000  cashflow              0.596655  operating activities             0.181159
#                                                                          ProceedsFromRepaymentsOfShortTermDebtMaturingInThreeMonthsOrLess    -3,193,000,000  cashflow              0.546430  financing activities             0.182305
#                                                                                                                    OperatingLeasePayments     4,000,000,000    income              0.658199  comprehensive income             0.185274
#                    ShareBasedCompensationArrangementByShareBasedPaymentAwardEquityInstrumentsOtherThanOptionsVestedInPeriodTotalFairValue    48,800,000,000    income              0.604274    Operating Expenses             0.187964
#                                                                                                                         OperatingExpenses   174,465,000,000    income              0.717912    Operating Expenses             0.189188
#                                                                                                NetCashProvidedByUsedInFinancingActivities  -351,157,000,000  cashflow              0.607118  financing activities             0.189664
#                               ShareBasedCompensationArrangementByShareBasedPaymentAwardEquityInstrumentsOtherThanOptionsForfeitedInPeriod         8,373,000    income              0.610227    Operating Expenses             0.191712
#                                                                                                                 OtherNoncashIncomeExpense     4,582,000,000    income              0.572469  operating activities             0.192172
#                                  ShareBasedCompensationArrangementByShareBasedPaymentAwardEquityInstrumentsOtherThanOptionsGrantsInPeriod        73,466,000    income              0.611780    Operating Expenses             0.193061
#                                                                                           ProceedsFromPaymentsForOtherFinancingActivities    -1,053,000,000  cashflow              0.605288  financing activities             0.194404
#                                  ShareBasedCompensationArrangementByShareBasedPaymentAwardEquityInstrumentsOtherThanOptionsVestedInPeriod        76,845,000    income              0.611004    Operating Expenses             0.194505
#                                                                                              StockRepurchasedAndRetiredDuringPeriodShares     1,774,463,000  cashflow              0.519357  financing activities             0.204043
#                                                                                                   ProceedsFromRepaymentsOfCommercialPaper    -2,050,000,000  cashflow              0.565339  financing activities             0.207384
#                                                                                           PaymentsForProceedsFromOtherInvestingActivities     4,125,000,000  cashflow              0.613837  investing activities             0.216278
#                                                                                               StockRepurchasedAndRetiredDuringPeriodValue   352,244,000,000  cashflow              0.533019  financing activities             0.216684
#                                          AdjustmentsToAdditionalPaidInCapitalSharebasedCompensationRequisiteServicePeriodRecognitionValue    36,418,000,000  cashflow              0.517022           disclosures             0.222744
#                                                                                                PaymentsToAcquirePropertyPlantAndEquipment    33,121,000,000  cashflow              0.567168  operating activities             0.224587
#                                                                                                      DepreciationDepletionAndAmortization    34,662,000,000    income              0.695873    Operating Expenses             0.227563
#                                                                               AdjustmentsRelatedToTaxWithholdingForShareBasedCompensation    17,332,000,000    income              0.683843    Operating Expenses             0.233093
#                                                                                                        PaymentsForRepurchaseOfCommonStock   263,210,000,000  cashflow              0.521966  financing activities             0.233370
#                                                                                  PaymentsRelatedToTaxWithholdingForShareBasedCompensation    28,532,000,000    income              0.673200    Operating Expenses             0.238532
#                                                                                                                       PaymentsOfDividends    45,680,000,000  cashflow              0.549128  financing activities             0.243282
#                                                                                                                              Depreciation    24,700,000,000    income              0.698418    Operating Expenses             0.247010
#                                                                                                           GeneralAndAdministrativeExpense    22,207,000,000    income              0.705693    Operating Expenses             0.255303
#                                                                                                                SellingAndMarketingExpense   112,846,000,000    income              0.695045    Operating Expenses             0.255504
#                                                                                                    SellingGeneralAndAdministrativeExpense    78,630,000,000    income              0.709846    Operating Expenses             0.257838
#                                                                                                             ResearchAndDevelopmentExpense    95,835,000,000    income              0.702875    Operating Expenses             0.258883
#                                                                    EmployeeServiceShareBasedCompensationTaxBenefitFromCompensationExpense    10,373,000,000    income              0.724303    Operating Expenses             0.276717
#                                                                                                                 NonoperatingIncomeExpense      -617,000,000    income              0.762134 nonoperating expenses             0.293332
#                                                                                                                        OperatingLeaseCost     4,100,000,000    income              0.735232    Operating Expenses             0.301321
#                                                                                                                    ShareBasedCompensation    35,384,000,000    income              0.715234    Operating Expenses             0.315427
#                                                                                                                         VariableLeaseCost    43,800,000,000    income              0.713823    Operating Expenses             0.324218
#                                                                                                    AllocatedShareBasedCompensationExpense    35,384,000,000    income              0.729610    Operating Expenses             0.327421
#                                                                                               IncreaseDecreaseInOtherOperatingLiabilities     7,507,000,000  cashflow              0.610085  operating activities             0.347390
#                                                                                                    IncreaseDecreaseInOtherOperatingAssets    26,612,000,000  cashflow              0.606622  operating activities             0.353243
#                                                  OtherComprehensiveIncomeUnrealizedHoldingGainLossOnSecuritiesArisingDuringPeriodNetOfTax     8,230,000,000    income              0.756684  comprehensive income             0.364475
#                                                                                                        IncreaseDecreaseInOtherReceivables       432,000,000  cashflow              0.629838  operating activities             0.367231
#
# ✓ Uncertain predictions saved to: uncertain_inc_cf_aapl.csv
#   Please review and manually annotate these predictions.
