# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import LinearSVC
from sklearn.metrics import confusion_matrix
from sklearn.calibration import CalibratedClassifierCV

from sklearn.model_selection import train_test_split

import numpy as np

# imports for pipeline to run
import requests
import re
import unicodedata
import os
import warnings

import logging

import argparse

import math

import matplotlib_inline

# for fetching previosu pipeline steps
import importlib

# previous pipeline step
import Sort_10K_by_Context_W3 as SortCxt

# updated
importlib.reload(SortCxt)

# options:
# word embeddings
# bag-of-words
# tf idf, confusion matrix to pick best classifier for csv annotation 

# using NLP for:

# task 1 - nlp
# use bal_sheet_example.csv for training
# copy bal_sheet_{ticker}_data.csv to nlp_bal_sheet_{ticker}_data.csv 
# annotate nlp_bal_sheet_{ticker}_data.csv with category column based on training 
# if there are labels in the nlp_bal_sheet_{ticker}_data.csv that are not present in the bal_sheet_example.csv, add (label, value, category) to the bal_sheet_example.csv where category is hypothesized

# task 2
# use income_&_cashflow_example.csv for training 
# copy inc_cf_{ticker}.csv to nlp_inc_cf_{ticker}.csv 
# annotate nlp_inc_cf_{ticker}.csv with statement column and category column based on training 
# if there are labels in the nlp_inc_cf_{ticker}.csv that are not present in the income_&_cashflow_example.csv, add (label, value, category) to the income_&_cashflow_example.csv where category is hypothesized

# task 3 - no nlp
# separate nlp_inc_cf_{ticker}.csv into two csvs: nlp_inc_{ticker}.csv and nlp_cf_{ticker}.csv based on statement column (if "income" -> nlp_inc_{ticker}.csv, if "cashflow" -> nlp_cf_{ticker}.csv)

# task 4 - no nlp
# reconstruct balance sheet from nlp_bal_sheet_{ticker}_data.csv, income statement from nlp_inc_{ticker}.csv, cashflow statement from nlp_cf_{ticker}.csv
# by placing items with the same value in category column together, ordered by size of value (smaller value first -> biggest listed last)

# parser
def parse_args():
    parser = argparse.ArgumentParser(description="Get confidence threshold")
    parser.add_argument("--confidence", help="confidence threshold", default=None)

    args, _ = parser.parse_known_args()

    while True:
        if not args.confidence:
            args.confidence = input("Confidence threshold (0.0-1.0): ")

        try:
            confidence_value = float(args.confidence)

            if 0.0 <= confidence_value <= 1.0:
                args.confidence = confidence_value
                break
            else:
                print("Error: Confidence threshold must be between 0 and 1")
                args.confidence = None  # Reset to retry

        except ValueError:
            print("Error: Enter a numeric value (e.g., 0.5)")
            args.confidence = None  # Reset to retry

    return args

def camelcase_tokenizer(text):
    # Split on camelCase boundaries
    tokens = re.findall(r'[A-Z]+(?=[A-Z][a-z]|\b)|[A-Z][a-z]+', text)
    return ' '.join(tokens)

def classify_income_cashflow_statement_type(train_df, test_df):
    # input:
    #     train_df: DataFrame with columns ['label', 'value', 'statement', 'category']
    #               (from income_&_cashflow_example.csv)
    #     test_df: DataFrame with columns ['label', 'value']

    # output:
    #     dictionary with classifier and "statement" predictions

    vectorizer = TfidfVectorizer(
        # since label items look like this: IncrementalCommonSharesAttributableToShareBasedPaymentArrangements
        tokenizer=camelcase_tokenizer,
        lowercase=False,
        min_df=1,           
        ngram_range=(1, 15)
    )

    X_full = vectorizer.fit_transform(train_df['label'])
    y_full = train_df['statement']  # "income" or "cashflow"

    # split into training and validation data
    X_train, X_val, y_train, y_val = train_test_split(X_full, y_full, test_size=0.3, random_state=0)

    # choose best for binary classification
    classifiers = {
        "LogisticRegression": LogisticRegression(random_state=0, max_iter=1000),
        #"LinearSVC": CalibratedClassifierCV(LinearSVC(random_state=0, max_iter=2000, dual=False), cv=2)
    }

    results = {}
    best_val_accuracy = -1
    best_classifier_name = None
    best_model = None

    for name, clf in classifiers.items():
        # Train on training set
        clf.fit(X_train, y_train)

        # Evaluate on validation set (unseen during training)
        val_accuracy = clf.score(X_val, y_val)

        results[name] = {
            'model': clf,
            'train_accuracy': clf.score(X_train, y_train),
            'val_accuracy': val_accuracy
        }

        print(f"{name}: train={clf.score(X_train, y_train):.4f}, val={val_accuracy:.4f}")

        if val_accuracy > best_val_accuracy:
            best_val_accuracy = val_accuracy
            best_classifier_name = name
            best_model = clf

    # Retrain best model on full training data
    best_model.fit(X_full, y_full)

    X_test = vectorizer.transform(test_df['label'])
    test_predictions = best_model.predict(X_test)
    test_probabilities = best_model.predict_proba(X_test)

    return {
        "best_classifier": best_classifier_name,
        "best_model": best_model,
        "vectorizer": vectorizer,
        "predictions": test_predictions,
        "probabilities": test_probabilities,
        "results": results,
        "val_accuracy": best_val_accuracy
    }

def classify_income_cashflow_bal_category(train_df, test_df): 
    # input:
    #     train_df: DataFrame with columns ['label', 'value', 'category']
    #               (from bal_sheet_example.csv)
    #     test_df: DataFrame with columns ['label', 'value'] 
    #              (from bal_sheet_{ticker}_data.csv, no category yet)

    # output:
    #     dictionary with best classifier, vectorizer, and predictions

    vectorizer = TfidfVectorizer(
        # since label items look like this: IncrementalCommonSharesAttributableToShareBasedPaymentArrangements
        tokenizer=camelcase_tokenizer,
        lowercase=False,
        min_df=1,           
        ngram_range=(1, 15)
    )

    # step 1 - data
    X_full = vectorizer.fit_transform(train_df['label'])
    y_full = train_df['category']

    # split: 70% train, 30% validate
    X_train, X_val, y_train, y_val = train_test_split(X_full, y_full, test_size=0.3, random_state=0)

    # step 2 - classifiers
    classifiers = {
        "LogisticRegression": LogisticRegression(random_state=0, max_iter=1000),
        "MultinomialNB": MultinomialNB(),
        "DecisionTreeClassifier": DecisionTreeClassifier(random_state=0, max_depth=5),
        #"LinearSVC": CalibratedClassifierCV(LinearSVC(random_state=0, max_iter=2000, dual=False), cv=2)
    }

    # step 3 - train and validate    
    results = {}
    best_val_accuracy = -1
    best_classifier_name = None
    best_model = None

    for name, clf in classifiers.items():
        # train on training set
        clf.fit(X_train, y_train)

        val_accuracy = clf.score(X_val, y_val)

        results[name] = {
            'model': clf,
            'train_accuracy': clf.score(X_train, y_train),
            'val_accuracy': val_accuracy
        }
        print(f"{name}: train={clf.score(X_train, y_train):.4f}, val={val_accuracy:.4f}")

        # pick best classifier
        if val_accuracy > best_val_accuracy:
            best_val_accuracy = val_accuracy
            best_classifier_name = name
            best_model = clf

    # retrain best model on full data set
    best_model.fit(X_full, y_full)

    # step 4 - predict on test data
    X_test = vectorizer.transform(test_df['label'])
    test_predictions = best_model.predict(X_test)

    # step 5 - prediction probabilities - to flag uncertain predictions
    test_probabilities = best_model.predict_proba(X_test)

    return {
        "best_classifier": best_classifier_name,
        "best_model": best_model,
        "vectorizer": vectorizer,
        "predictions": test_predictions,
        "probabilities": test_probabilities,
        "results": results,
        "training_accuracy": best_val_accuracy
    }

def flag_uncertain_predictions(original_train_df, annotated_test_df, 
                             confidence_threshold=0.5, output_file=None):
    # input:
    #     original_train_df: original training CSV (for reference only)
    #     annotated_test_df: annotated test CSV with predictions and confidence scores
    #     confidence_threshold: predictions below this threshold are flagged as uncertain
    #     output_file: path to save uncertain predictions CSV

    # output:
    #     DataFrame containing only uncertain predictions

    # identify uncertain predictions
    if 'statement' in annotated_test_df.columns:
        # income/cashflow case - if either statement or category confidence is below threshold
        uncertain_mask = (
            (annotated_test_df['statement_confidence'] < confidence_threshold) |
            (annotated_test_df['category_confidence'] < confidence_threshold)
        )
    else:
        # balance sheet case: check if category confidence is below threshold
        uncertain_mask = annotated_test_df['prediction_confidence'] < confidence_threshold

    # copy uncertain predictions into a separate file
    uncertain_df = annotated_test_df[uncertain_mask].copy()

    # if there re no uncertain predictions, return the original dataset
    if len(uncertain_df) == 0:
        print(f"✓ No uncertain predictions found (threshold: {confidence_threshold})")
        return pd.DataFrame()

    # Sort by confidence (lowest first) so highest priority uncertain cases appear first
    if 'statement' in uncertain_df.columns:
        # Use minimum confidence of both columns
        uncertain_df['min_confidence'] = uncertain_df[['statement_confidence', 'category_confidence']].min(axis=1)
        uncertain_df = uncertain_df.sort_values('min_confidence')
        uncertain_df = uncertain_df.drop(columns=['min_confidence'])
    else:
        uncertain_df = uncertain_df.sort_values('prediction_confidence')

    #summary
    print(f"\n⚠ Found {len(uncertain_df)} uncertain predictions (threshold: {confidence_threshold}):")
    print(f"  Require manual review and annotation.\n")

    # Select columns to display
    cols_to_display = ['label', 'value']
    if 'statement' in uncertain_df.columns:
        cols_to_display.extend(['statement', 'statement_confidence', 'category', 'category_confidence'])
    else:
        cols_to_display.extend(['category', 'prediction_confidence'])

    print(uncertain_df[cols_to_display].to_string(index=False))

    # Save to CSV if output file specified
    if output_file:
        uncertain_df.to_csv(output_file, index=False)
        print(f"\n✓ Uncertain predictions saved to: {output_file}")
        print(f"  Please review and manually annotate these predictions.")

    return uncertain_df

def separate_income_cashflow(ticker):

    # split nlp_inc_cf_{ticker}.csv into two files based on 'statement' column.

    df = pd.read_csv(f'nlp_inc_cf_{ticker}.csv')

    # Filter by statement type
    income_df = df[df['statement'].str.lower() == 'income'].copy()
    cashflow_df = df[df['statement'].str.lower() == 'cashflow'].copy()

    # drop the 'statement' column
    income_df = income_df.drop(columns=['statement'])
    cashflow_df = cashflow_df.drop(columns=['statement'])

    # sort by category and value so that it resembles proper format
    income_df = income_df.sort_values(by=['category', 'value']).reset_index(drop=True)
    cashflow_df = cashflow_df.sort_values(by=['category', 'value']).reset_index(drop=True)

    return income_df, cashflow_df

def main():

    # Run previous pipeline steps
    ticker = SortCxt.main()

    args = parse_args()

    confidence_threshold = float(args.confidence)

    # task 1
    # get training dataset for balance sheet # label, value, category
    bal_sheet_train = pd.read_csv('bal_sheet_example.csv')

    # print("Testing tokenizer on first 5 labels:\n")
    # for i, label in enumerate(bal_sheet_train['label'].head()):
    #     tokens = camelcase_tokenizer(label)
    #     print(f"{i+1}. {label}")
    #     print(f"   Tokens: {tokens}")
    #     print(f"   Count: {len(tokens)}\n")

    # get test dataset # label, value
    bal_sheet_test = pd.read_csv(f'bal_sheet_{ticker}_data.csv') 

    # classify labels by balance sheet categories
    bal_sheet_results = classify_income_cashflow_bal_category(bal_sheet_train, bal_sheet_test)

    # add predictions to test data (balance sheet)
    bal_sheet_test['category'] = bal_sheet_results['predictions']
    bal_sheet_test['prediction_confidence'] = bal_sheet_results['probabilities'].max(axis=1)

    # sort by category and value so that it resembles proper format
    bal_sheet_test= bal_sheet_test.sort_values(by=['category', 'value']).reset_index(drop=True)

    # save annotated balance sheet file
    bal_sheet_test.to_csv(f'nlp_bal_sheet_{ticker}_data.csv', index=False)

    # task 2
    # get training dataset for income and cashflow statement # label, value, statement, category
    income_cashflow_train = pd.read_csv('income_&_cashflow_example.csv')

    # get test dataset # label, value
    income_cashflow_test = pd.read_csv(f'inc_cf_{ticker}_data.csv')

    # classify statement type
    statement_results = classify_income_cashflow_bal_category(income_cashflow_train, income_cashflow_test)
    income_cashflow_test['statement'] = statement_results['predictions']
    income_cashflow_test['statement_confidence'] = statement_results['probabilities'].max(axis=1)

    # classify category
    category_results = classify_income_cashflow_bal_category(income_cashflow_train, income_cashflow_test)
    income_cashflow_test['category'] = category_results['predictions']
    income_cashflow_test['category_confidence'] = category_results['probabilities'].max(axis=1)

    # save annotated file
    income_cashflow_test.to_csv(f'nlp_inc_cf_{ticker}.csv', index=False)

    # get df's for income and cashflow
    income_df, cashflow_df = separate_income_cashflow(ticker)

    # write to separate csv's income and cashflow
    income_df.to_csv(f'nlp_inc_{ticker}.csv', index=False)
    print(f"Income statement: {len(income_df)} rows in nlp_inc_{ticker}.csv")

    cashflow_df.to_csv(f'nlp_cf_{ticker}.csv', index=False)
    print(f"Cashflow statement: {len(cashflow_df)} rows in nlp_cf_{ticker}.csv")

    # Balance sheet uncertain predictions
    bal_sheet_uncertain = flag_uncertain_predictions(
        bal_sheet_train,
        bal_sheet_test,
        confidence_threshold=confidence_threshold,
        output_file=f'uncertain_bal_sheet_{ticker}.csv'
    )

    # Income/cashflow uncertain predictions
    inc_cf_uncertain = flag_uncertain_predictions(
        income_cashflow_train,
        income_cashflow_test,
        confidence_threshold=confidence_threshold,
        output_file=f'uncertain_inc_cf_{ticker}.csv'
    )

    return ticker

if __name__ == "__main__":
    main()
# Out:
# Company ticker:  aapl
# Year:  2015
# Found CIK 0000320193 for ticker aapl
# https://data.sec.gov/submissions/CIK0000320193.json
# DEBUG: 10-K filings for 2015: 1
#   - 2015-10-28: 10-K
# DEBUG: Checking year 2015, found 1 filings
# https://www.sec.gov/Archives/edgar/data/320193/000119312515356351/index.json
# No instance document found in 2015 filings, trying 2016...
# DEBUG: 10-K filings for 2016: 1
#   - 2016-10-26: 10-K
# DEBUG: Checking year 2016, found 1 filings
# https://www.sec.gov/Archives/edgar/data/320193/000162828016020309/index.json
# No instance document found in 2016 filings, trying 2017...
# DEBUG: 10-K filings for 2017: 1
#   - 2017-11-03: 10-K
# DEBUG: Checking year 2017, found 1 filings
# https://www.sec.gov/Archives/edgar/data/320193/000032019317000070/index.json
# No instance document found in 2017 filings, trying 2018...
# DEBUG: 10-K filings for 2018: 1
#   - 2018-11-05: 10-K
# DEBUG: Checking year 2018, found 1 filings
# https://www.sec.gov/Archives/edgar/data/320193/000032019318000145/index.json
# No instance document found in 2018 filings, trying 2019...
# DEBUG: 10-K filings for 2019: 1
#   - 2019-10-31: 10-K
# DEBUG: Checking year 2019, found 1 filings
# https://www.sec.gov/Archives/edgar/data/320193/000032019319000119/index.json
# Found filing with required XMLs at: https://www.sec.gov/Archives/edgar/data/320193/000032019319000119/index.json
# {'a10-k20199282019_htm.xml': 'https://www.sec.gov/Archives/edgar/data/320193/000032019319000119/a10-k20199282019_htm.xml', 'aapl-20190928_cal.xml': 'https://www.sec.gov/Archives/edgar/data/320193/000032019319000119/aapl-20190928_cal.xml', 'aapl-20190928_def.xml': 'https://www.sec.gov/Archives/edgar/data/320193/000032019319000119/aapl-20190928_def.xml', 'aapl-20190928_lab.xml': 'https://www.sec.gov/Archives/edgar/data/320193/000032019319000119/aapl-20190928_lab.xml', 'aapl-20190928_pre.xml': 'https://www.sec.gov/Archives/edgar/data/320193/000032019319000119/aapl-20190928_pre.xml'}
# Downloaded: a10-k20199282019_htm.xml
# Downloaded: aapl-20190928_cal.xml
# Downloaded: aapl-20190928_def.xml
# Downloaded: aapl-20190928_lab.xml
# Downloaded: aapl-20190928_pre.xml
# DEBUG: uri_to_prefix has 11 entries
# DEBUG: Found 301 contexts and 9 units
# DEBUG: Found 1312 facts
# Created: sec_xbrl_content_aapl.csv, sec_xbrl_values_aapl.csv, sec_xbrl_contexts_aapl.csv, sec_xbrl_facts_aapl.csv
# ✓ Added to dict_csvs: sec_xbrl_content_aapl.csv
# ✓ Added to dict_csvs: sec_xbrl_values_aapl.csv
# ✓ Added to dict_csvs: sec_xbrl_contexts_aapl.csv
# ✓ Added to dict_csvs: sec_xbrl_facts_aapl.csv
#
# Total metrics in context: 98
#
# Total metrics in context: 1
#
# Total metrics in context: 0
#
# Total metrics in context: 1
#
# Total metrics in context: 121
#
# Total metrics in context: 1
#
# Total metrics in context: 0
#
# Total metrics in context: 1
#
# Total metrics in context: 1
#
# Total metrics in context: 2
#
# Total metrics in context: 2
#
# Total metrics in context: 1
#
# Total metrics in context: 1
#
# Total metrics in context: 1
#
# Total metrics in context: 1
#
# Total metrics in context: 1
#
# Total metrics in context: 0
#
# Total metrics in context: 1
#
# Total metrics in context: 2
#
# Total metrics in context: 1
#
# Total metrics in context: 2
#
# Total metrics in context: 3
#
# Total metrics in context: 1
#
# Total metrics in context: 1
# ✓ Appended to: bal_sheet_aapl_data.csv
# ✓ Appended to: aapl_data.csv
# ✓ Appended to: aapl_data.csv
# ✓ Appended to: inc_cf_aapl_data.csv
# ✓ Appended to: aapl_data.csv
# ✓ Appended to: bal_sheet_aapl_data.csv
# ✓ Appended to: bal_sheet_aapl_data.csv
# ✓ Appended to: aapl_data.csv
# ✓ Appended to: aapl_data.csv
# ✓ Appended to: aapl_data.csv
# ✓ Appended to: aapl_data.csv
# ✓ Appended to: aapl_data.csv
# ✓ Appended to: aapl_data.csv
# ✓ Appended to: aapl_data.csv
# ✓ Appended to: aapl_data.csv
# ✓ Appended to: aapl_data.csv
# ✓ Appended to: aapl_data.csv
# ✓ Appended to: aapl_data.csv
# ✓ Appended to: aapl_data.csv
# ✓ Appended to: aapl_data.csv
# ✓ Appended to: aapl_data.csv
# Confidence threshold (0.0-1.0):  0.3
# /home/phlka_pug/anaconda3/lib/python3.13/site-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# LogisticRegression: train=0.8734, val=0.6000
# MultinomialNB: train=0.8481, val=0.4857
# DecisionTreeClassifier: train=0.7848, val=0.2857
# /home/phlka_pug/anaconda3/lib/python3.13/site-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# LogisticRegression: train=0.8939, val=0.4483
# MultinomialNB: train=0.7576, val=0.4138
# DecisionTreeClassifier: train=0.6061, val=0.4483
# /home/phlka_pug/anaconda3/lib/python3.13/site-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# LogisticRegression: train=0.8939, val=0.4483
# MultinomialNB: train=0.7576, val=0.4138
# DecisionTreeClassifier: train=0.6061, val=0.4483
# Income statement: 0 rows in nlp_inc_aapl.csv
# Cashflow statement: 0 rows in nlp_cf_aapl.csv
#
# ⚠ Found 156 uncertain predictions (threshold: 0.3):
#   Require manual review and annotation.
#
#                                                                                     label           value               category  prediction_confidence
#                                                        DerivativeFairValueOfDerivativeNet    -269,000,000   subtotal liabilities               0.174233
#                                                        DerivativeFairValueOfDerivativeNet    -719,000,000   subtotal liabilities               0.174233
#                                                                                      Cash  55,466,000,000         current assets               0.182184
#                                                             HedgedLiabilityFairValueHedge  26,100,000,000    current liabilities               0.189065
#                                                               CommitmentsAndContingencies             NaN      noncurrent assets               0.193358
#                                                               CommitmentsAndContingencies             NaN      noncurrent assets               0.193358
#                                                               CommitmentsAndContingencies             NaN      noncurrent assets               0.193358
#                                                  ShortTermDebtWeightedAverageInterestRate               0      noncurrent assets               0.194457
#                                                  ShortTermDebtWeightedAverageInterestRate               0      noncurrent assets               0.194457
#                                                  ShortTermDebtWeightedAverageInterestRate               0      noncurrent assets               0.194457
#                                        DeferredTaxLiabilitiesUndistributedForeignEarnings     605,000,000    current liabilities               0.195216
#                                            DeferredTaxLiabilitiesOtherComprehensiveIncome     712,000,000                 equity               0.205935
#                                                 DeferredTaxLiabilitiesLeasingArrangements   1,862,000,000    current liabilities               0.206223
#                                                 DeferredTaxLiabilitiesLeasingArrangements   4,425,000,000    current liabilities               0.206223
#                                                          LiabilitiesAndStockholdersEquity 662,404,000,000                 equity               0.208554
#                                                          LiabilitiesAndStockholdersEquity 704,241,000,000                 equity               0.208554
#                                                          LiabilitiesAndStockholdersEquity 724,221,000,000                 equity               0.208554
#                                                   StockRepurchaseProgramAuthorizedAmount1 225,000,000,000                 equity               0.211958
#                                                            StandardProductWarrantyAccrual  14,798,000,000      noncurrent assets               0.212711
#                                                            StandardProductWarrantyAccrual  14,450,000,000      noncurrent assets               0.212711
#                                             DebtInstrumentInterestRateEffectivePercentage               0      noncurrent assets               0.217242
#                                             DebtInstrumentInterestRateEffectivePercentage               0      noncurrent assets               0.217242
#                                                           DeferredTaxAssetsLiabilitiesNet  16,579,000,000      noncurrent assets               0.217717
#                                                           DeferredTaxAssetsLiabilitiesNet  16,202,000,000      noncurrent assets               0.217717
#                                                           DeferredTaxAssetsLiabilitiesNet  39,182,000,000      noncurrent assets               0.217717
#                                                               DeferredTaxLiabilitiesOther   1,305,000,000    current liabilities               0.218751
#                                                               DeferredTaxLiabilitiesOther   1,133,000,000    current liabilities               0.218751
#                                                               DeferredTaxLiabilitiesOther     957,000,000    current liabilities               0.218751
#                                                DebtInstrumentInterestRateStatedPercentage               0      noncurrent assets               0.221463
#                                                DebtInstrumentInterestRateStatedPercentage               0      noncurrent assets               0.221463
# EmployeeServiceShareBasedCompensationNonvestedAwardsTotalCompensationCostNotYetRecognized  12,200,000,000      noncurrent assets               0.226045
# EmployeeServiceShareBasedCompensationNonvestedAwardsTotalCompensationCostNotYetRecognized  10,500,000,000      noncurrent assets               0.226045
#                                                              DeferredIncomeTaxLiabilities  21,733,000,000      noncurrent assets               0.228487
#                                                              DeferredIncomeTaxLiabilities  12,371,000,000      noncurrent assets               0.228487
#                                                              DeferredIncomeTaxLiabilities  14,276,000,000      noncurrent assets               0.228487
#                                    LongTermDebtMaturitiesRepaymentsOfPrincipalInYearThree   9,528,000,000      noncurrent assets               0.229915
#                                    LongTermDebtMaturitiesRepaymentsOfPrincipalInYearThree  11,389,000,000      noncurrent assets               0.229915
#                                    LongTermDebtMaturitiesRepaymentsOfPrincipalInYearThree   9,300,000,000      noncurrent assets               0.229915
#                                                                              InventoryNet   8,167,000,000      noncurrent assets               0.232168
#                                                                              InventoryNet  13,004,000,000      noncurrent assets               0.232168
#                                                                              InventoryNet   8,062,000,000      noncurrent assets               0.232168
#                                                      DerivativeFairValueOfDerivativeAsset   8,588,000,000        subtotal assets               0.232750
#                                                      DerivativeFairValueOfDerivativeAsset   7,475,000,000        subtotal assets               0.232750
#                                      LongTermDebtMaturitiesRepaymentsOfPrincipalInYearTwo  10,078,000,000      noncurrent assets               0.233998
#                                      LongTermDebtMaturitiesRepaymentsOfPrincipalInYearTwo   8,750,000,000      noncurrent assets               0.233998
#                                      LongTermDebtMaturitiesRepaymentsOfPrincipalInYearTwo   9,569,000,000      noncurrent assets               0.233998
#                                     LongTermDebtMaturitiesRepaymentsOfPrincipalInYearFour   9,290,000,000      noncurrent assets               0.234270
#                                     LongTermDebtMaturitiesRepaymentsOfPrincipalInYearFour   5,235,000,000      noncurrent assets               0.234270
#                                     LongTermDebtMaturitiesRepaymentsOfPrincipalInYearFour  10,115,000,000      noncurrent assets               0.234270
#                                     LongTermDebtMaturitiesRepaymentsOfPrincipalInYearFive  10,914,000,000      noncurrent assets               0.240998
#                                     LongTermDebtMaturitiesRepaymentsOfPrincipalInYearFive  10,039,000,000      noncurrent assets               0.240998
#                                     LongTermDebtMaturitiesRepaymentsOfPrincipalInYearFive   4,972,000,000      noncurrent assets               0.240998
#      DeferredTaxAssetsTaxDeferredExpenseCompensationAndBenefitsShareBasedCompensationCost   1,262,000,000      noncurrent assets               0.242887
#                                           DeferredTaxAssetsTaxCreditCarryforwardsResearch   4,000,000,000      noncurrent assets               0.244283
#                                            DeferredTaxAssetsTaxCreditCarryforwardsForeign   4,700,000,000      noncurrent assets               0.245798
#                                                   DeferredTaxAssetsTaxCreditCarryforwards  17,499,000,000      noncurrent assets               0.246944
#                                  LongTermDebtMaturitiesRepaymentsOfPrincipalAfterYearFive  49,303,000,000      noncurrent assets               0.247597
#                                  LongTermDebtMaturitiesRepaymentsOfPrincipalAfterYearFive  55,341,000,000      noncurrent assets               0.247597
#                                  LongTermDebtMaturitiesRepaymentsOfPrincipalAfterYearFive  53,802,000,000      noncurrent assets               0.247597
#                                                                                    Assets 724,221,000,000      noncurrent assets               0.251614
#                                                                                    Assets 662,404,000,000      noncurrent assets               0.251614
#                                                                                    Assets 704,241,000,000      noncurrent assets               0.251614
#                                                                NontradeReceivablesCurrent  66,013,000,000    current liabilities               0.253949
#                                                                NontradeReceivablesCurrent  48,687,000,000    current liabilities               0.253949
#                                                                NontradeReceivablesCurrent  44,203,000,000    current liabilities               0.253949
#                                                                              LongTermDebt 187,340,000,000 noncurrent liabilities               0.255835
#                                    DeferredTaxAssetsTaxDeferredExpenseReservesAndAccruals   8,540,000,000      noncurrent assets               0.256056
#                                    DeferredTaxAssetsTaxDeferredExpenseReservesAndAccruals  12,268,000,000      noncurrent assets               0.256056
#                                    DeferredTaxAssetsTaxDeferredExpenseReservesAndAccruals  10,130,000,000      noncurrent assets               0.256056
#                                                               MarketableSecuritiesCurrent 160,502,000,000         current assets               0.257043
#                                                               MarketableSecuritiesCurrent 223,907,000,000         current assets               0.257043
#                                                               MarketableSecuritiesCurrent 209,280,000,000         current assets               0.257043
#                                UnrecordedUnconditionalPurchaseObligationDueAfterFiveYears     130,000,000    current liabilities               0.261125
#                                UnrecordedUnconditionalPurchaseObligationDueAfterFiveYears     773,000,000    current liabilities               0.261125
#                                UnrecordedUnconditionalPurchaseObligationDueAfterFiveYears     110,000,000    current liabilities               0.261125
#                                                                   OperatingLeaseLiability   9,181,000,000   subtotal liabilities               0.261172
#                                                                   OperatingLeaseLiability  12,490,000,000   subtotal liabilities               0.261172
#                                                                               Liabilities 506,606,000,000    current liabilities               0.263018
#                                                                               Liabilities 593,538,000,000    current liabilities               0.263018
#                                                                               Liabilities 506,577,000,000    current liabilities               0.263018
#                             LongTermDebtMaturitiesRepaymentsOfPrincipalInNextTwelveMonths  10,270,000,000    current liabilities               0.263335
#                             LongTermDebtMaturitiesRepaymentsOfPrincipalInNextTwelveMonths  12,393,000,000    current liabilities               0.263335
#                             LongTermDebtMaturitiesRepaymentsOfPrincipalInNextTwelveMonths   8,750,000,000    current liabilities               0.263335
#                                                              DebtInstrumentCarryingAmount 513,444,000,000 noncurrent liabilities               0.263397
#                                                              DebtInstrumentCarryingAmount 279,903,000,000 noncurrent liabilities               0.263397
#                                                              DebtInstrumentCarryingAmount 521,614,000,000 noncurrent liabilities               0.263397
#                                                                    DeferredTaxAssetsGross  39,723,000,000      noncurrent assets               0.265968
#                                                                    DeferredTaxAssetsGross  73,290,000,000      noncurrent assets               0.265968
#                                           DeferredTaxLiabilitiesPropertyPlantAndEquipment   5,827,000,000      noncurrent assets               0.266368
#                                                                     FinanceLeaseLiability   1,230,000,000    current liabilities               0.267477
#                                                                     FinanceLeaseLiability     661,000,000    current liabilities               0.267477
#                                        OperatingLeasesFutureMinimumPaymentsDueInFiveYears     834,000,000 noncurrent liabilities               0.267918
#                                                   OperatingLeasesFutureMinimumPaymentsDue  21,638,000,000 noncurrent liabilities               0.268017
#                                                         OtherAccruedLiabilitiesNoncurrent  36,283,000,000    current liabilities               0.270275
#                                                         OtherAccruedLiabilitiesNoncurrent  47,278,000,000    current liabilities               0.270275
#                                                                    DeferredTaxAssetsOther   6,390,000,000      noncurrent assets               0.270513
#                                                                    DeferredTaxAssetsOther   1,494,000,000      noncurrent assets               0.270513
#                                                                    DeferredTaxAssetsOther   4,583,000,000      noncurrent assets               0.270513
#                                           AccumulatedOtherComprehensiveIncomeLossNetOfTax    -990,000,000                 equity               0.272258
#                                           AccumulatedOtherComprehensiveIncomeLossNetOfTax -12,743,000,000                 equity               0.272258
#                                           AccumulatedOtherComprehensiveIncomeLossNetOfTax  -4,038,000,000                 equity               0.272258
#                                            OperatingLeasesFutureMinimumPaymentsDueCurrent   1,306,000,000    current liabilities               0.272851
#                                                       DeferredTaxAssetsValuationAllowance  19,832,000,000      noncurrent assets               0.273296
#                                                       DeferredTaxAssetsValuationAllowance   1,788,000,000      noncurrent assets               0.273296
#                                                        RetainedEarningsAccumulatedDeficit 116,298,000,000                 equity               0.275606
#                                                        RetainedEarningsAccumulatedDeficit -33,418,000,000                 equity               0.275606
#                                                        RetainedEarningsAccumulatedDeficit  60,864,000,000                 equity               0.275606
#                                                                     LiabilitiesNoncurrent 284,959,000,000 noncurrent liabilities               0.278149
#                                                                     LiabilitiesNoncurrent 251,515,000,000 noncurrent liabilities               0.278149
#                                                                     LiabilitiesNoncurrent 295,467,000,000 noncurrent liabilities               0.278149
#                                                           DeferredTaxAssetsDeferredIncome   2,513,000,000      noncurrent assets               0.278884
#                                                           DeferredTaxAssetsDeferredIncome   3,010,000,000      noncurrent assets               0.278884
#                                                           DeferredTaxAssetsDeferredIncome   6,366,000,000      noncurrent assets               0.278884
#                                         OperatingLeasesFutureMinimumPaymentsDueThereafter   5,373,000,000 noncurrent liabilities               0.279269
#                                                                     RestrictedInvestments  39,200,000,000      noncurrent assets               0.280253
#                                                                     RestrictedInvestments  37,500,000,000      noncurrent assets               0.280253
#                                                  EquitySecuritiesFvNiCurrentAndNoncurrent  15,042,000,000         current assets               0.282760
#                                                  DerivativeFairValueOfDerivativeLiability   7,199,000,000   subtotal liabilities               0.283079
#                                                  DerivativeFairValueOfDerivativeLiability   5,923,000,000   subtotal liabilities               0.283079
#                                                              AccruedIncomeTaxesNoncurrent  63,134,000,000 noncurrent liabilities               0.284268
#                                                              AccruedIncomeTaxesNoncurrent  57,715,000,000 noncurrent liabilities               0.284268
#                               UnrecordedUnconditionalPurchaseObligationBalanceSheetAmount  13,831,000,000    current liabilities               0.285035
#                               UnrecordedUnconditionalPurchaseObligationBalanceSheetAmount   8,652,000,000    current liabilities               0.285035
#                               UnrecordedUnconditionalPurchaseObligationBalanceSheetAmount   8,211,000,000    current liabilities               0.285035
#                       UnrecordedUnconditionalPurchaseObligationBalanceOnSecondAnniversary   3,708,000,000    current liabilities               0.286205
#                       UnrecordedUnconditionalPurchaseObligationBalanceOnSecondAnniversary   2,885,000,000    current liabilities               0.286205
#                       UnrecordedUnconditionalPurchaseObligationBalanceOnSecondAnniversary   2,386,000,000    current liabilities               0.286205
#                               UnrecognizedTaxBenefitsIncomeTaxPenaltiesAndInterestAccrued   2,700,000,000 noncurrent liabilities               0.286466
#                               UnrecognizedTaxBenefitsIncomeTaxPenaltiesAndInterestAccrued   2,700,000,000 noncurrent liabilities               0.286466
#            DebtSecuritiesAvailableForSaleContinuousUnrealizedLossPositionLessThan12Months 154,389,000,000      noncurrent assets               0.287292
#                                        OperatingLeasesFutureMinimumPaymentsDueInFourYears     912,000,000 noncurrent liabilities               0.287848
#                                                                        StockholdersEquity 487,002,000,000                 equity               0.288110
#                                                                        StockholdersEquity 792,188,000,000                 equity               0.288110
#                                                                        StockholdersEquity 915,674,000,000                 equity               0.288110
#                                                                     LongTermDebtFairValue 224,600,000,000 noncurrent liabilities               0.288615
#                                                                     LongTermDebtFairValue 168,800,000,000 noncurrent liabilities               0.288615
#                                                                     LongTermDebtFairValue 210,700,000,000 noncurrent liabilities               0.288615
#                                         OperatingLeasesFutureMinimumPaymentsDueInTwoYears   1,276,000,000 noncurrent liabilities               0.289786
#                       UnrecordedUnconditionalPurchaseObligationBalanceOnFourthAnniversary   1,306,000,000    current liabilities               0.290213
#                       UnrecordedUnconditionalPurchaseObligationBalanceOnFourthAnniversary   1,162,000,000    current liabilities               0.290213
#                       UnrecordedUnconditionalPurchaseObligationBalanceOnFourthAnniversary     357,000,000    current liabilities               0.290213
#                        UnrecordedUnconditionalPurchaseObligationBalanceOnFirstAnniversary   2,476,000,000    current liabilities               0.292853
#                        UnrecordedUnconditionalPurchaseObligationBalanceOnFirstAnniversary   4,752,000,000    current liabilities               0.292853
#                        UnrecordedUnconditionalPurchaseObligationBalanceOnFirstAnniversary   3,476,000,000    current liabilities               0.292853
#                        UnrecordedUnconditionalPurchaseObligationBalanceOnThirdAnniversary   1,700,000,000    current liabilities               0.293081
#                        UnrecordedUnconditionalPurchaseObligationBalanceOnThirdAnniversary   1,859,000,000    current liabilities               0.293081
#                        UnrecordedUnconditionalPurchaseObligationBalanceOnThirdAnniversary   1,981,000,000    current liabilities               0.293081
#                        UnrecordedUnconditionalPurchaseObligationBalanceOnFifthAnniversary     104,000,000    current liabilities               0.294556
#                        UnrecordedUnconditionalPurchaseObligationBalanceOnFifthAnniversary     218,000,000    current liabilities               0.294556
#                        UnrecordedUnconditionalPurchaseObligationBalanceOnFifthAnniversary     788,000,000    current liabilities               0.294556
#                                                RestrictedCashAndCashEquivalentsNoncurrent   3,094,000,000         current assets               0.295974
#                                                RestrictedCashAndCashEquivalentsNoncurrent   1,357,000,000         current assets               0.295974
#                                                                      DeferredTaxAssetsNet  37,935,000,000      noncurrent assets               0.298192
#                                                                      DeferredTaxAssetsNet  53,458,000,000      noncurrent assets               0.298192
#                                                                      DeferredTaxAssetsNet  26,250,000,000      noncurrent assets               0.298192
#                                       OperatingLeasesFutureMinimumPaymentsDueInThreeYears   1,137,000,000 noncurrent liabilities               0.299002
#
# ✓ Uncertain predictions saved to: uncertain_bal_sheet_aapl.csv
#   Please review and manually annotate these predictions.
#
# ⚠ Found 184 uncertain predictions (threshold: 0.3):
#   Require manual review and annotation.
#
#                                                                                                                                     label             value             statement  statement_confidence              category  category_confidence
#                                                                                            StandardProductWarrantyAccrualWarrantiesIssued    12,162,000,000  operating activities              0.111227  operating activities             0.111227
#                                                                                                                                  Revenues        -8,000,000    Operating Expenses              0.111544    Operating Expenses             0.111544
#                                                                                                       InvestmentIncomeInterestAndDividend    15,848,000,000  financing activities              0.112752  financing activities             0.112752
#                                                                                                      CommonStockDividendsPerShareDeclared                 2  financing activities              0.115444  financing activities             0.115444
#                                                                                                      CommonStockDividendsPerShareDeclared                 8  financing activities              0.115444  financing activities             0.115444
#                                                                                                    DeferredForeignIncomeTaxExpenseBenefit     1,620,000,000    Operating Expenses              0.115866    Operating Expenses             0.115866
#                                                                                                    DeferredForeignIncomeTaxExpenseBenefit     3,831,000,000    Operating Expenses              0.115866    Operating Expenses             0.115866
#                                                                                                EffectiveIncomeTaxRateContinuingOperations                 0  comprehensive income              0.116128  comprehensive income             0.116128
#                                                                                                EffectiveIncomeTaxRateContinuingOperations                 0  comprehensive income              0.116128  comprehensive income             0.116128
#                                                                     AntidilutiveSecuritiesExcludedFromComputationOfEarningsPerShareAmount        15,500,000  comprehensive income              0.116409  comprehensive income             0.116409
#                                               IncomeLossFromContinuingOperationsBeforeIncomeTaxesExtraordinaryItemsNoncontrollingInterest   201,540,000,000  comprehensive income              0.116522  comprehensive income             0.116522
#                                               IncomeLossFromContinuingOperationsBeforeIncomeTaxesExtraordinaryItemsNoncontrollingInterest   369,950,000,000  comprehensive income              0.116522  comprehensive income             0.116522
#                                                                                                           DeferredIncomeTaxExpenseBenefit   -26,964,000,000    Operating Expenses              0.116738    Operating Expenses             0.116738
#                                                                                       RevenueFromContractWithCustomerExcludingAssessedTax 4,041,661,000,000  operating activities              0.116823  operating activities             0.116823
#                                                                                       RevenueFromContractWithCustomerExcludingAssessedTax 5,457,990,000,000  operating activities              0.116823  operating activities             0.116823
#                                                                                        ForeignIncomeTaxExpenseBenefitContinuingOperations    13,450,000,000    Operating Expenses              0.117236    Operating Expenses             0.117236
#                                                                                        ForeignIncomeTaxExpenseBenefitContinuingOperations    44,744,000,000    Operating Expenses              0.117236    Operating Expenses             0.117236
#                                                                                                                           InterestPaidNet     8,537,000,000    Operating Expenses              0.117255    Operating Expenses             0.117255
#                                                             IncomeTaxReconciliationIncomeTaxExpenseBenefitAtFederalStatutoryIncomeTaxRate    77,690,000,000  comprehensive income              0.117491  comprehensive income             0.117491
#                                                             IncomeTaxReconciliationIncomeTaxExpenseBenefitAtFederalStatutoryIncomeTaxRate    54,126,000,000  comprehensive income              0.117491  comprehensive income             0.117491
#                                                                                                            CurrentIncomeTaxExpenseBenefit    10,200,000,000    Operating Expenses              0.117512    Operating Expenses             0.117512
#                                                                                                    DeferredFederalIncomeTaxExpenseBenefit    -8,528,000,000    Operating Expenses              0.119255    Operating Expenses             0.119255
#                                                                                                    DeferredFederalIncomeTaxExpenseBenefit   -30,778,000,000    Operating Expenses              0.119255    Operating Expenses             0.119255
#                                                                                              DeferredStateAndLocalIncomeTaxExpenseBenefit      -486,000,000    Operating Expenses              0.119564    Operating Expenses             0.119564
#                                                                                              DeferredStateAndLocalIncomeTaxExpenseBenefit       -17,000,000    Operating Expenses              0.119564    Operating Expenses             0.119564
#                                                                                  StateAndLocalIncomeTaxExpenseBenefitContinuingOperations     1,268,000,000    Operating Expenses              0.119790    Operating Expenses             0.119790
#                                                                                  StateAndLocalIncomeTaxExpenseBenefitContinuingOperations     4,490,000,000    Operating Expenses              0.119790    Operating Expenses             0.119790
#                                                                                        FederalIncomeTaxExpenseBenefitContinuingOperations    24,873,000,000    Operating Expenses              0.119862    Operating Expenses             0.119862
#                                                                                        FederalIncomeTaxExpenseBenefitContinuingOperations    17,975,000,000    Operating Expenses              0.119862    Operating Expenses             0.119862
#                                                                                                                               GrossProfit   545,032,000,000  comprehensive income              0.120764  comprehensive income             0.120764
#                                                                                                                               GrossProfit   488,648,000,000  comprehensive income              0.120764  comprehensive income             0.120764
#                                                                                                                CostOfGoodsAndServicesSold   932,620,000,000    Operating Expenses              0.121812    Operating Expenses             0.121812
#                                                                                                                CostOfGoodsAndServicesSold 1,936,347,000,000    Operating Expenses              0.121812    Operating Expenses             0.121812
#                                                                                            ContractWithCustomerLiabilityRevenueRecognized    18,000,000,000               Revenue              0.121882               Revenue             0.121882
#                                                                                            ContractWithCustomerLiabilityRevenueRecognized    24,126,000,000               Revenue              0.121882               Revenue             0.121882
#                                                                                                                   IncomeTaxExpenseBenefit    67,209,000,000    Operating Expenses              0.122046    Operating Expenses             0.122046
#                                                                                                                   IncomeTaxExpenseBenefit    39,591,000,000    Operating Expenses              0.122046    Operating Expenses             0.122046
#                                                                        DefinedContributionPlanMaximumAnnualContributionsPerEmployeeAmount            19,000  comprehensive income              0.122577  comprehensive income             0.122577
#                                                                                                 IncomeTaxReconciliationTaxCreditsResearch     1,786,000,000  comprehensive income              0.124610  comprehensive income             0.124610
#                                                                                                 IncomeTaxReconciliationTaxCreditsResearch     3,658,000,000  comprehensive income              0.124610  comprehensive income             0.124610
#                                                             UnrecognizedTaxBenefitsDecreasesResultingFromSettlementsWithTaxingAuthorities     4,851,000,000  operating activities              0.124771  operating activities             0.124771
#                                                             UnrecognizedTaxBenefitsDecreasesResultingFromSettlementsWithTaxingAuthorities     2,147,000,000  operating activities              0.124771  operating activities             0.124771
#                                                                                                                        IncomeTaxesPaidNet    37,271,000,000  comprehensive income              0.125260  comprehensive income             0.125260
#                                                                                                                        IncomeTaxesPaidNet    88,150,000,000  comprehensive income              0.125260  comprehensive income             0.125260
#                                                                      UnrecognizedTaxBenefitsDecreasesResultingFromPriorPeriodTaxPositions     1,920,000,000  comprehensive income              0.125680  comprehensive income             0.125680
#                                                                      UnrecognizedTaxBenefitsDecreasesResultingFromPriorPeriodTaxPositions     3,850,000,000  comprehensive income              0.125680  comprehensive income             0.125680
#                                                                                                           CurrentForeignTaxExpenseBenefit    58,924,000,000    Operating Expenses              0.126297    Operating Expenses             0.126297
#                                                                                                           CurrentForeignTaxExpenseBenefit     9,619,000,000    Operating Expenses              0.126297    Operating Expenses             0.126297
#                                                                      UnrecognizedTaxBenefitsIncreasesResultingFromPriorPeriodTaxPositions     8,609,000,000  comprehensive income              0.127926  comprehensive income             0.127926
#                                                                      UnrecognizedTaxBenefitsIncreasesResultingFromPriorPeriodTaxPositions     5,742,000,000  comprehensive income              0.127926  comprehensive income             0.127926
#                                                       UnrecognizedTaxBenefitsReductionsResultingFromLapseOfApplicableStatuteOfLimitations     2,275,000,000  comprehensive income              0.128938  comprehensive income             0.128938
#                                                       UnrecognizedTaxBenefitsReductionsResultingFromLapseOfApplicableStatuteOfLimitations       118,000,000  comprehensive income              0.128938  comprehensive income             0.128938
#                            CashCashEquivalentsRestrictedCashAndRestrictedCashEquivalentsPeriodIncreaseDecreaseIncludingExchangeRateEffect    29,740,000,000  operating activities              0.129423  operating activities             0.129423
#                            CashCashEquivalentsRestrictedCashAndRestrictedCashEquivalentsPeriodIncreaseDecreaseIncludingExchangeRateEffect    10,957,000,000  operating activities              0.129423  operating activities             0.129423
#                                                                                                     CurrentStateAndLocalTaxExpenseBenefit     4,976,000,000    Operating Expenses              0.130499    Operating Expenses             0.130499
#                                                                                                     CurrentStateAndLocalTaxExpenseBenefit     1,285,000,000    Operating Expenses              0.130499    Operating Expenses             0.130499
#                                                                                                           CurrentFederalTaxExpenseBenefit    21,703,000,000    Operating Expenses              0.130992    Operating Expenses             0.130992
#                                                                                                           CurrentFederalTaxExpenseBenefit    55,651,000,000    Operating Expenses              0.130992    Operating Expenses             0.130992
#                                                                                           IncomeTaxReconciliationStateAndLocalIncomeTaxes       879,000,000  comprehensive income              0.132436  comprehensive income             0.132436
#                                                                        IncomeTaxReconciliationChangeInDeferredTaxAssetsValuationAllowance     2,091,000,000  comprehensive income              0.132557  comprehensive income             0.132557
#                                                                       EffectiveIncomeTaxRateReconciliationAtFederalStatutoryIncomeTaxRate                 0  comprehensive income              0.132633  comprehensive income             0.132633
#                                                                       EffectiveIncomeTaxRateReconciliationAtFederalStatutoryIncomeTaxRate                 0  comprehensive income              0.132633  comprehensive income             0.132633
#                                                                                IncomeLossFromContinuingOperationsBeforeIncomeTaxesForeign   232,200,000,000  comprehensive income              0.132792  comprehensive income             0.132792
#                                                                                IncomeLossFromContinuingOperationsBeforeIncomeTaxesForeign   137,000,000,000  comprehensive income              0.132792  comprehensive income             0.132792
#                                                                                   IncomeTaxReconciliationForeignIncomeTaxRateDifferential   -14,366,000,000  comprehensive income              0.133823  comprehensive income             0.133823
#                                                                                   IncomeTaxReconciliationForeignIncomeTaxRateDifferential   -19,175,000,000  comprehensive income              0.133823  comprehensive income             0.133823
#                                                                                           PaymentsToAcquireAvailableForSaleSecuritiesDebt   102,576,000,000  comprehensive income              0.137154  comprehensive income             0.137154
#                                                                                           PaymentsToAcquireAvailableForSaleSecuritiesDebt   270,472,000,000  comprehensive income              0.137154  comprehensive income             0.137154
#                                                                                    ProceedsFromShortTermDebtMaturingInMoreThanThreeMonths    46,361,000,000  financing activities              0.137855  financing activities             0.137855
#                                                                                    ProceedsFromShortTermDebtMaturingInMoreThanThreeMonths     5,836,000,000  financing activities              0.137855  financing activities             0.137855
#                                                                                                                       OperatingIncomeLoss   741,134,000,000 nonoperating expenses              0.139756 nonoperating expenses             0.139756
#                                                                                                                       OperatingIncomeLoss   703,818,000,000 nonoperating expenses              0.139756 nonoperating expenses             0.139756
#                                                                         EffectiveIncomeTaxRateReconciliationTaxCutsAndJobsActOf2017Amount     1,515,000,000  comprehensive income              0.139858  comprehensive income             0.139858
#                                                                                          ProceedsFromSaleOfAvailableForSaleSecuritiesDebt   199,390,000,000  comprehensive income              0.141084  comprehensive income             0.141084
#                                                                                          ProceedsFromSaleOfAvailableForSaleSecuritiesDebt    29,853,000,000  comprehensive income              0.141084  comprehensive income             0.141084
#                                                                     ProceedsFromMaturitiesPrepaymentsAndCallsOfAvailableForSaleSecurities   131,804,000,000  comprehensive income              0.141568  comprehensive income             0.141568
# ...
#    ShareBasedCompensationArrangementByShareBasedPaymentAwardEquityInstrumentsOtherThanOptionsForfeituresWeightedAverageGrantDateFairValue               183    Operating Expenses              0.180311    Operating Expenses             0.180311
#                                                                                                NetCashProvidedByUsedInOperatingActivities   211,050,000,000  operating activities              0.181159  operating activities             0.181159
#                                                                                                NetCashProvidedByUsedInOperatingActivities   340,279,000,000  operating activities              0.181159  operating activities             0.181159
#                                                                          ProceedsFromRepaymentsOfShortTermDebtMaturingInThreeMonthsOrLess    -3,193,000,000  financing activities              0.182305  financing activities             0.182305
#                                                                          ProceedsFromRepaymentsOfShortTermDebtMaturingInThreeMonthsOrLess    -3,986,000,000  financing activities              0.182305  financing activities             0.182305
#                                                                                                         PaymentsToAcquireOtherInvestments     3,393,000,000  investing activities              0.182684  investing activities             0.182684
#                                                                                                                    OperatingLeasePayments     4,000,000,000  comprehensive income              0.185274  comprehensive income             0.185274
#                    ShareBasedCompensationArrangementByShareBasedPaymentAwardEquityInstrumentsOtherThanOptionsVestedInPeriodTotalFairValue    48,800,000,000    Operating Expenses              0.187964    Operating Expenses             0.187964
#                    ShareBasedCompensationArrangementByShareBasedPaymentAwardEquityInstrumentsOtherThanOptionsVestedInPeriodTotalFairValue    22,300,000,000    Operating Expenses              0.187964    Operating Expenses             0.187964
#                                                                                                                         OperatingExpenses   174,465,000,000    Operating Expenses              0.189188    Operating Expenses             0.189188
#                                                                                                                         OperatingExpenses    92,245,000,000    Operating Expenses              0.189188    Operating Expenses             0.189188
#                                                                                                NetCashProvidedByUsedInFinancingActivities  -196,826,000,000  financing activities              0.189664  financing activities             0.189664
#                                                                                                NetCashProvidedByUsedInFinancingActivities  -351,157,000,000  financing activities              0.189664  financing activities             0.189664
#                                                                                                         ProceedsFromIssuanceOfCommonStock     2,005,000,000  financing activities              0.190801  financing activities             0.190801
#                                                                                                                           InterestExpense     9,139,000,000    Operating Expenses              0.191076    Operating Expenses             0.191076
#                               ShareBasedCompensationArrangementByShareBasedPaymentAwardEquityInstrumentsOtherThanOptionsForfeitedInPeriod        17,346,000    Operating Expenses              0.191712    Operating Expenses             0.191712
#                               ShareBasedCompensationArrangementByShareBasedPaymentAwardEquityInstrumentsOtherThanOptionsForfeitedInPeriod         8,373,000    Operating Expenses              0.191712    Operating Expenses             0.191712
#                                                                                                                 OtherNoncashIncomeExpense     4,582,000,000  operating activities              0.192172  operating activities             0.192172
#                                                                                                                 OtherNoncashIncomeExpense     1,262,000,000  operating activities              0.192172  operating activities             0.192172
#                                  ShareBasedCompensationArrangementByShareBasedPaymentAwardEquityInstrumentsOtherThanOptionsGrantsInPeriod       132,315,000    Operating Expenses              0.193061    Operating Expenses             0.193061
#                                  ShareBasedCompensationArrangementByShareBasedPaymentAwardEquityInstrumentsOtherThanOptionsGrantsInPeriod        73,466,000    Operating Expenses              0.193061    Operating Expenses             0.193061
#                                                                                           ProceedsFromPaymentsForOtherFinancingActivities    -1,053,000,000  financing activities              0.194404  financing activities             0.194404
#                                                                                           ProceedsFromPaymentsForOtherFinancingActivities      -105,000,000  financing activities              0.194404  financing activities             0.194404
#                                  ShareBasedCompensationArrangementByShareBasedPaymentAwardEquityInstrumentsOtherThanOptionsVestedInPeriod        76,845,000    Operating Expenses              0.194505    Operating Expenses             0.194505
#                                  ShareBasedCompensationArrangementByShareBasedPaymentAwardEquityInstrumentsOtherThanOptionsVestedInPeriod       132,541,000    Operating Expenses              0.194505    Operating Expenses             0.194505
#                                                                                                             OperatingLeasesRentExpenseNet     3,600,000,000    Operating Expenses              0.201094    Operating Expenses             0.201094
#                                                          EffectiveIncomeTaxRateReconciliationShareBasedCompensationExcessTaxBenefitAmount    -1,314,000,000    Operating Expenses              0.202020    Operating Expenses             0.202020
#                                                                                              StockRepurchasedAndRetiredDuringPeriodShares     1,404,450,000  financing activities              0.204043  financing activities             0.204043
#                                                                                              StockRepurchasedAndRetiredDuringPeriodShares     1,774,463,000  financing activities              0.204043  financing activities             0.204043
#                                                                                                   ProceedsFromRepaymentsOfCommercialPaper    -2,050,000,000  financing activities              0.207384  financing activities             0.207384
#                                                                                                   ProceedsFromRepaymentsOfCommercialPaper    -2,162,000,000  financing activities              0.207384  financing activities             0.207384
#                                                                                           PaymentsForProceedsFromOtherInvestingActivities     1,947,000,000  investing activities              0.216278  investing activities             0.216278
#                                                                                           PaymentsForProceedsFromOtherInvestingActivities     4,125,000,000  investing activities              0.216278  investing activities             0.216278
#                                                                                               StockRepurchasedAndRetiredDuringPeriodValue   352,244,000,000  financing activities              0.216684  financing activities             0.216684
#                                                                                               StockRepurchasedAndRetiredDuringPeriodValue   240,258,000,000  financing activities              0.216684  financing activities             0.216684
#                                          AdjustmentsToAdditionalPaidInCapitalSharebasedCompensationRequisiteServicePeriodRecognitionValue    16,546,000,000           disclosures              0.222744           disclosures             0.222744
#                                          AdjustmentsToAdditionalPaidInCapitalSharebasedCompensationRequisiteServicePeriodRecognitionValue    36,418,000,000           disclosures              0.222744           disclosures             0.222744
#                                                                                                PaymentsToAcquirePropertyPlantAndEquipment    33,121,000,000  operating activities              0.224587  operating activities             0.224587
#                                                                                                PaymentsToAcquirePropertyPlantAndEquipment    36,259,000,000  operating activities              0.224587  operating activities             0.224587
#                                                                                                      DepreciationDepletionAndAmortization    33,607,000,000    Operating Expenses              0.227563    Operating Expenses             0.227563
#                                                                                                      DepreciationDepletionAndAmortization    34,662,000,000    Operating Expenses              0.227563    Operating Expenses             0.227563
#                                                                               AdjustmentsRelatedToTaxWithholdingForShareBasedCompensation    17,332,000,000    Operating Expenses              0.233093    Operating Expenses             0.233093
#                                                                               AdjustmentsRelatedToTaxWithholdingForShareBasedCompensation     7,806,000,000    Operating Expenses              0.233093    Operating Expenses             0.233093
#                                                                                                        PaymentsForRepurchaseOfCommonStock   263,210,000,000  financing activities              0.233370  financing activities             0.233370
#                                                                                                        PaymentsForRepurchaseOfCommonStock   172,535,000,000  financing activities              0.233370  financing activities             0.233370
#                                                                                  PaymentsRelatedToTaxWithholdingForShareBasedCompensation    28,532,000,000    Operating Expenses              0.238532    Operating Expenses             0.238532
#                                                                                  PaymentsRelatedToTaxWithholdingForShareBasedCompensation    14,918,000,000    Operating Expenses              0.238532    Operating Expenses             0.238532
#                                                                        ReclassificationFromAociCurrentPeriodBeforeTaxAttributableToParent    -1,200,000,000  comprehensive income              0.239746  comprehensive income             0.239746
#                                                                                                                       PaymentsOfDividends    40,600,000,000  financing activities              0.243282  financing activities             0.243282
#                                                                                                                       PaymentsOfDividends    45,680,000,000  financing activities              0.243282  financing activities             0.243282
#                                                                                      SharesPaidForTaxWithholdingForShareBasedCompensation        46,200,000    Operating Expenses              0.243590    Operating Expenses             0.243590
#                                                                                                                              Depreciation    28,800,000,000    Operating Expenses              0.247010    Operating Expenses             0.247010
#                                                                                                                              Depreciation    24,700,000,000    Operating Expenses              0.247010    Operating Expenses             0.247010
#                                                                                                           GeneralAndAdministrativeExpense    22,207,000,000    Operating Expenses              0.255303    Operating Expenses             0.255303
#                                                                                                                SellingAndMarketingExpense   112,846,000,000    Operating Expenses              0.255504    Operating Expenses             0.255504
#                                                                                                    SellingGeneralAndAdministrativeExpense    50,211,000,000    Operating Expenses              0.257838    Operating Expenses             0.257838
#                                                                                                    SellingGeneralAndAdministrativeExpense    78,630,000,000    Operating Expenses              0.257838    Operating Expenses             0.257838
#                                                                                                             ResearchAndDevelopmentExpense    95,835,000,000    Operating Expenses              0.258883    Operating Expenses             0.258883
#                                                                                                             ResearchAndDevelopmentExpense    42,034,000,000    Operating Expenses              0.258883    Operating Expenses             0.258883
#                                                                                             ProceedsFromSaleAndMaturityOfOtherInvestments     2,113,000,000  investing activities              0.264048  investing activities             0.264048
#                                                                    EmployeeServiceShareBasedCompensationTaxBenefitFromCompensationExpense    10,373,000,000    Operating Expenses              0.276717    Operating Expenses             0.276717
#                                                                    EmployeeServiceShareBasedCompensationTaxBenefitFromCompensationExpense     5,492,000,000    Operating Expenses              0.276717    Operating Expenses             0.276717
#                                                                                                                 NonoperatingIncomeExpense      -617,000,000 nonoperating expenses              0.293332 nonoperating expenses             0.293332
#                                                                                                                 NonoperatingIncomeExpense     5,413,000,000 nonoperating expenses              0.293332 nonoperating expenses             0.293332
#                                                                                                            OtherNonoperatingIncomeExpense      -152,000,000 nonoperating expenses              0.294396 nonoperating expenses             0.294396
#
# ✓ Uncertain predictions saved to: uncertain_inc_cf_aapl.csv
#   Please review and manually annotate these predictions.
