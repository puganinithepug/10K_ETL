# %%
import pandas as pd
from collections import defaultdict

import importlib

import os

import Merge_Filing_Data_W2 as MFD

importlib.reload(MFD)

def make_numeric(some_str):
    try:
        return int(some_str)
    except (ValueError, TypeError):
        try:
            return float(some_str)
        except (ValueError, TypeError):
            return some_str  # Return original if not numeric


def building_disjoints(sort_ctx_by_type):
    shared_items = {}
    
    disjoint_sets = {}
    
    items_sorted = list(sort_ctx_by_type.items())
    
    for i in range(len(items_sorted)):
        for j in range(i + 1, len(items_sorted)):
            key1, values1 = items_sorted[i]
            key2, values2 = items_sorted[j]
    
            inters = values1.intersection(values2)
    
            values1d = values1 - values2
            values2d = values2 - values1
    
            key_s = key1 + "_" + key2
            key_1d = key1 +"d"
            key_2d = key2 +"d"
    
            value_s = inters	
    
            disjoint_sets[key_1d] = values1d
            disjoint_sets[key_2d] = values2d
    
            shared_items[key_s]=value_s
            
            # shared = values1 & values2
            # if shared:
            #     new_key = key1+"_"+key2
            #     shared_items[new_key]

    return shared_items, disjoint_sets
            
def compare_with_default(csv_bal, csv_inc_cf, df):
    # for comparing disjoint sets against data in bal_sheet_snapshot.csv and income_cashflow_term.csv
    # key assumption to test if context refs are organized by instant vs periodic
    # therefore need to see which of the data's intersection is none zero with disjoint defaults
    # a set has none zero intersection with income_cashflow_term.csv then it shouldnt intersect wit bal_sheet_snapshot.csv
    # so test for nonzero intersection with one of the csv and zero intersection with the other csv

    # get label column from the csv_filename and compare with labels in dataset

    df_bal = pd.read_csv(csv_bal)
    df_inc_cf = pd.read_csv(csv_inc_cf)

    if len(set(df_bal['label']).intersection(set(df['label'])))>0 and len(set(df_inc_cf['label']).intersection((set(df['label']))))==0:
            return "B"
    
    elif len(set(df_bal['label']).intersection(set(df['label'])))==0 and len(set(df_inc_cf['label']).intersection((set(df['label']))))>0:
        return "IC"

    return None  

def merge_contexts_by_shared_tags(items_list):
    merged = True
    while merged:
        merged = False
        i = 0
        
        while i < len(items_list):
            current_key, current_val = items_list[i]
            current_tags = set(tag for tag, val in current_val)
            
            j = i + 1
            while j < len(items_list):
                next_key, next_val = items_list[j]
                next_tags = set(tag for tag, val in next_val)
                
                if current_tags.intersection(next_tags):
                    merged_key = current_key + "_" + next_key
                    merged_val = list(set(current_val + next_val))
                    items_list[i] = (merged_key, merged_val)
                    items_list.pop(j)
                    
                    current_key, current_val = merged_key, merged_val
                    current_tags = set(tag for tag, val in merged_val)
                    merged = True
                    # Don't increment j; check next item in shortened list
                else:
                    j += 1
            
            i += 1
    
    return items_list


def main():

    merged_file, ticker = MFD.main()

    #merged_file = "merged_sec_xbrl_aapl.csv"

    #ticker = merged_file.split('_')[2].split('.')[0]


    # check for us-gaap tag presence before doing anything

    
    # Load your merged SEC XBRL CSV
    df = pd.read_csv(merged_file)
    print(f"Columns: {df.columns.tolist()}")

    # Optional: save context frequency
    df['contextRef'].value_counts().to_csv(f"SEC_contextRefs_{ticker}.csv")

    print("contextRef done")
    
    # Build dictionary of lists grouped by context
    sort_by_context = defaultdict(list)
    
    # for every cxt ref key in sort_by_context if value list has at least one same tag, merge lists, for context ref keys make a new key which is a string conctenation of the context refs
    sort_ctx_by_type = defaultdict(list)
    
    for _, row in df.iterrows():
        if row['tag_prefix'] == 'us-gaap':
            context = row['contextRef']
            tag = row['tag_local']
            
            if "TextBlock" in tag:
                continue
            val = row['value_raw']
            sort_by_context[context].append((tag, val))
    #A context is a set or grouping of reported facts.  
    #Each reported fact has a taxonomy element and value in an XBRL document such as a financial report.  
    #A context groups together all the facts that share the same reporting period and certain other characteristics.

    # #---- builds sort_by_context
    #sort_by_context = builds_sort_by_context(sort_by_context, df)
        
    # # for every cxt ref key in sort_by_context if value list has at least one same tag, merge lists, for context ref keys make a new key which is a string conctenation of the context refs
    items_list = list(sort_by_context.items())

    new_items_list = merge_contexts_by_shared_tags(items_list)
    
    # for ctx, facts in items_list:
    for ctx, facts in new_items_list:
        # Rebuild facts list with converted values
        tag_dict = {}
        for tag, val in facts:
            num = make_numeric(val)
            if isinstance(num, str):
                continue
            if tag in tag_dict:
                tag_dict[tag]+=num
            else:
                tag_dict[tag]=num
    
        converted_facts = [(tag, val) for tag, val in tag_dict.items()]
    
        print(f"\nTotal metrics in context: {len(converted_facts)}")
        
        if len(converted_facts) >= 1:
            sort_ctx_by_type[ctx] = converted_facts
            print(ctx)
            print(converted_facts)
            print()

        #---- builds sort_ctx_by_type

    #new_items_list = builds_sort_ctx_by_typeA(items_list)        
    #new_sort_ctx_by_type = builds_sort_ctx_by_typeB(sort_ctx_by_type, new_items_list, ticker)

    for ctx, converted_facts in sort_ctx_by_type.items():
    
        if len(converted_facts) >= 1:  
                    
            df = pd.DataFrame(converted_facts, columns=['label', 'value'])
            df['value'] = df['value'].apply(lambda x: f"{int(x):,}" if pd.notna(x) else '')

            df['context'] = ctx  # tracks which context each row came from
    
            csv_bal = "bal_sheet_example.csv"
            csv_inc_cf = "income_&_cashflow_example.csv"
            
            # check to see which one is bal and which one is cashflow/income by finding one thhat matches criteria:
            # meaning it has zero intersection for one sheet info and nonzero with other

            # balance sheet
            if compare_with_default(csv_bal, csv_inc_cf, df) == "B":
                filename = f'bal_sheet_{ticker}_data.csv'
            # income statement
            elif compare_with_default(csv_bal, csv_inc_cf, df) == "IC":
                filename = f'inc_cf_{ticker}_data.csv'
            else:     
                filename = f'{ticker}_data.csv'
                
            if os.path.exists(filename):
                df.to_csv(filename, mode='a', header=False, index=False)
                print(f"✓ Appended to: {filename}")
            else:
                df.to_csv(filename, index=False)
                print(f"✓ Created and exported to: {filename}")
                    
if __name__ == "__main__":
    main()
# Out:
# Company ticker meta
# Year:  2020
# Found CIK 0001326801 for ticker meta
# https://data.sec.gov/submissions/CIK0001326801.json
# DEBUG: 10-K filings for 2020: 0
# DEBUG: Checking year 2020, found 0 filings
# No 10-K filings found for 2020, trying 2021...
# DEBUG: 10-K filings for 2021: 0
# DEBUG: Checking year 2021, found 0 filings
# No 10-K filings found for 2021, trying 2022...
# DEBUG: 10-K filings for 2022: 0
# DEBUG: Checking year 2022, found 0 filings
# No 10-K filings found for 2022, trying 2023...
# DEBUG: 10-K filings for 2023: 0
# DEBUG: Checking year 2023, found 0 filings
# No 10-K filings found for 2023, trying 2024...
# DEBUG: 10-K filings for 2024: 0
# DEBUG: Checking year 2024, found 0 filings
# No 10-K filings found for 2024, trying 2025...
# DEBUG: 10-K filings for 2025: 1
#   - 2025-01-30: 10-K
# DEBUG: Checking year 2025, found 1 filings
# https://www.sec.gov/Archives/edgar/data/1326801/000132680125000017/index.json
# Found filing with required XMLs at: https://www.sec.gov/Archives/edgar/data/1326801/000132680125000017/index.json
# {'meta-20241231_cal.xml': 'https://www.sec.gov/Archives/edgar/data/1326801/000132680125000017/meta-20241231_cal.xml', 'meta-20241231_def.xml': 'https://www.sec.gov/Archives/edgar/data/1326801/000132680125000017/meta-20241231_def.xml', 'meta-20241231_htm.xml': 'https://www.sec.gov/Archives/edgar/data/1326801/000132680125000017/meta-20241231_htm.xml', 'meta-20241231_lab.xml': 'https://www.sec.gov/Archives/edgar/data/1326801/000132680125000017/meta-20241231_lab.xml', 'meta-20241231_pre.xml': 'https://www.sec.gov/Archives/edgar/data/1326801/000132680125000017/meta-20241231_pre.xml'}
# Already exists: meta-20241231_cal.xml
# Already exists: meta-20241231_def.xml
# Already exists: meta-20241231_htm.xml
# Already exists: meta-20241231_lab.xml
# Already exists: meta-20241231_pre.xml
# DEBUG: uri_to_prefix has 14 entries
# DEBUG: Found 305 contexts and 14 units
# DEBUG: Found 1269 facts
# NOTE: 15 unmapped facts found. Inspect 'sec_xbrl_facts_meta.csv' and storage_values['_unmapped_facts']
# Created: sec_xbrl_content_meta.csv, sec_xbrl_values_meta.csv, sec_xbrl_contexts_meta.csv, sec_xbrl_facts_meta.csv
# ✓ Added to dict_csvs: sec_xbrl_content_meta.csv
# ✓ Added to dict_csvs: sec_xbrl_values_meta.csv
# ✓ Added to dict_csvs: sec_xbrl_contexts_meta.csv
# ✓ Added to dict_csvs: sec_xbrl_facts_meta.csv
# {'sec_xbrl_content_meta.csv': '/home/phlka_pug/10K_ETL/sec_xbrl_content_meta.csv', 'sec_xbrl_values_meta.csv': '/home/phlka_pug/10K_ETL/sec_xbrl_values_meta.csv', 'sec_xbrl_contexts_meta.csv': '/home/phlka_pug/10K_ETL/sec_xbrl_contexts_meta.csv', 'sec_xbrl_facts_meta.csv': '/home/phlka_pug/10K_ETL/sec_xbrl_facts_meta.csv'}
# Columns: ['tag_prefix', 'tag_local', 'gaap_candidate', 'contextRef', 'unitRef', 'decimals', 'value_raw', 'entity_identifier', 'period_start', 'period_end', 'instant']
# Columns: ['tag_prefix', 'tag_local', 'gaap_candidate', 'contextRef', 'unitRef', 'decimals', 'value_raw', 'entity_identifier', 'period_start', 'period_end', 'instant']
# contextRef done
#
# Total metrics in context: 0
#
# Total metrics in context: 128
# c-5_c-6_c-8_c-9_c-10_c-13_c-14_c-15_c-16_c-17_c-22_c-23_c-24_c-25_c-26_c-31_c-32_c-33_c-34_c-39_c-40_c-41_c-42_c-139_c-140_c-141_c-142_c-143_c-144_c-145_c-146_c-147_c-148_c-149_c-150_c-151_c-152_c-153_c-154_c-155_c-156_c-157_c-158_c-159_c-160_c-161_c-162_c-163_c-164_c-165_c-166_c-167_c-168_c-169_c-170_c-171_c-172_c-173_c-174_c-175_c-176_c-177_c-178_c-179_c-180_c-181_c-182_c-183_c-184_c-185_c-186_c-187_c-188_c-189_c-190_c-191_c-192_c-193_c-194_c-195_c-196_c-197_c-198_c-199_c-200_c-223_c-224_c-225_c-226_c-227_c-228_c-230_c-231_c-233_c-234_c-236_c-237_c-239_c-240_c-246_c-247_c-250_c-251_c-254_c-255_c-296_c-297_c-298_c-299_c-7
# [('DebtSecuritiesAvailableForSaleContinuousUnrealizedLossPositionLessThan12Months', 22676000000), ('DebtSecuritiesAvailableForSaleUnrealizedLossPositionAccumulatedLoss', 2830000000), ('StockRepurchaseProgramRemainingAuthorizedRepurchaseAmount1', 82210000000), ('NoncurrentAssets', 492298000000), ('FiniteLivedIntangibleAssetsNet', 1706000000), ('StockholdersEquity', 1172794000000), ('MarketableSecuritiesCurrent', 114934000000), ('DebtSecuritiesAvailableForSaleContinuousUnrealizedLossPosition12MonthsOrLonger', 66354000000), ('CashAndCashEquivalentsFairValueDisclosure', 216804000000), ('FinanceLeaseLiabilityPaymentsDueYearThree', 68000000), ('DeferredTaxAssetsUnrealizedLossesOnAvailableforSaleSecuritiesGross', 347000000), ('DebtSecuritiesAvailableForSaleUnrealizedLossPosition', 89030000000), ('CashCashEquivalentsRestrictedCashAndRestrictedCashEquivalents', 120726000000), ('PropertyPlantAndEquipmentAndFinanceLeaseRightOfUseAssetAccumulatedDepreciationAndAmortization', 76451000000), ('DeferredTaxAssetsOperatingLossCarryforwards', 642000000), ('DebtSecuritiesAvailableForSaleExcludingAccruedInterest', 88941000000), ('FiniteLivedIntangibleAssetsAmortizationExpenseYearTwo', 125000000), ('DebtSecuritiesAvailableForSaleContinuousUnrealizedLossPosition12MonthsOrLongerAccumulatedLoss', 2624000000), ('AvailableForSaleSecuritiesDebtMaturitiesAfterOneThroughFiveYearsFairValue', 24853000000), ('AssetsFairValueDisclosure', 263873000000), ('RetainedEarningsAccumulatedDeficit', 184576000000), ('ContractWithCustomerLiability', 1447000000), ('LesseeOperatingLeaseLiabilityPaymentsDueYearTwo', 2625000000), ('UnrecordedUnconditionalPurchaseObligationBalanceSheetAmount', 34120000000), ('OperatingLeaseLiabilityCurrent', 3565000000), ('DebtInstrumentCarryingAmount', 76500000000), ('CommonStockSharesOutstanding', 15545000000), ('AccruedIncomeTaxesNoncurrent', 17501000000), ('LongTermDebtMaturitiesRepaymentsOfPrincipalInYearThree', 2750000000), ('FiniteLivedIntangibleAssetsAmortizationExpenseYearFive', 23000000), ('FiniteLivedIntangibleAssetsAccumulatedAmortization', 1816000000), ('FiniteLivedIntangibleAssetsAmortizationExpenseYearFour', 38000000), ('FinanceLeaseLiabilityPaymentsDue', 892000000), ('AccruedLiabilitiesCurrent', 49455000000), ('PropertyPlantAndEquipmentAndFinanceLeaseRightOfUseAssetBeforeAccumulatedDepreciationAndAmortization', 294384000000), ('DebtSecuritiesAvailableForSaleContinuousUnrealizedLossPositionLessThan12MonthsAccumulatedLoss', 206000000), ('IncomeTaxExaminationPenaltiesAndInterestAccrued', 4760000000.0), ('LongTermDebtNoncurrent', 47211000000), ('CommonStockSharesAuthorized', 9141000000), ('DeferredTaxLiabilitiesPropertyPlantAndEquipment', 19279000000), ('LesseeOperatingLeaseLiabilityPaymentsDue', 25729000000), ('AccumulatedOtherComprehensiveIncomeLossNetOfTax', -5252000000), ('OtherAccruedLiabilitiesCurrent', 12443000000), ('FinanceLeaseLiabilityCurrent', 76000000), ('LesseeOperatingLeaseLiabilityPaymentsDueYearFive', 2391000000), ('FiniteLivedIntangibleAssetsGross', 3522000000), ('FinanceLeaseLiability', 709000000), ('PropertyPlantAndEquipmentAndFinanceLeaseRightOfUseAssetAfterAccumulatedDepreciationAndAmortization', 217933000000), ('DeferredTaxAssetsOther', 929000000), ('TaxesPayableCurrent', 7093000000), ('LiabilitiesCurrent', 65556000000), ('DeferredTaxAssetsGross', 45814000000), ('OperatingLeaseLiabilityNoncurrent', 35518000000), ('RestrictedCashAndCashEquivalentsAtCarryingValue', 746000000), ('UnrecognizedTaxBenefits', 62491000000), ('ContractualObligation', 65644000000), ('AccountsPayableTradeCurrent', 12536000000), ('AccumulatedOtherComprehensiveIncomeLossForeignCurrencyTranslationAdjustmentNetOfTax', -3900000000), ('AdditionalPaidInCapital', 156481000000), ('LesseeOperatingLeaseLiabilityPaymentsDueNextTwelveMonths', 2657000000), ('EquitySecuritiesWithoutReadilyDeterminableFairValueAmount', 12101000000), ('EmployeeServiceShareBasedCompensationNonvestedAwardsTotalCompensationCostNotYetRecognized', 34790000000), ('FinanceLea ...
#
#
# Total metrics in context: 109
# c-1_c-11_c-12_c-19_c-20_c-21_c-28_c-29_c-30_c-36_c-37_c-38_c-59_c-60_c-61_c-62_c-63_c-64_c-65_c-66_c-67_c-68_c-69_c-70_c-71_c-72_c-73_c-74_c-75_c-76_c-77_c-78_c-79_c-80_c-81_c-82_c-83_c-84_c-85_c-86_c-87_c-88_c-133_c-134_c-135_c-136_c-137_c-138_c-213_c-214_c-215_c-266_c-267_c-268_c-269_c-270_c-271_c-272_c-273_c-275_c-276_c-277_c-278_c-279_c-280_c-281_c-282_c-283_c-284_c-285_c-286_c-18_c-27_c-35
# [('OperatingIncomeLoss', 290150000000), ('LaborAndRelatedExpense', 230916000000), ('WeightedAverageNumberOfSharesOutstandingBasic', 15590000000), ('ShareBasedCompensation', 42709000000), ('PaymentsForRepurchaseOfCommonStock', 77855000000), ('UnrecognizedTaxBenefitsIncreasesResultingFromCurrentPeriodTaxPositions', 5252000000), ('AmortizationOfIntangibleAssets', 557000000), ('OperatingLeasePayments', 6717000000), ('UnrecognizedTaxBenefitsIncreasesResultingFromPriorPeriodTaxPositions', 1063000000), ('OtherComprehensiveIncomeLossNetOfTaxPortionAttributableToParent', -2404000000), ('OtherCostAndExpenseOperating', 310958000000), ('AllocatedShareBasedCompensationExpense', 85418000000), ('PaymentsForProceedsFromOtherInvestingActivities', -102000000), ('RevenueFromContractWithCustomerExcludingAssessedTax', 1853997000000), ('ProceedsFromIssuanceOfLongTermDebt', 28808000000), ('ComprehensiveIncomeNetOfTax', 122254000000), ('CurrentStateAndLocalTaxExpenseBenefit', 2226000000), ('InterestPaidNet', 934000000), ('CashCashEquivalentsRestrictedCashAndRestrictedCashEquivalentsPeriodIncreaseDecreaseIncludingExchangeRateEffect', 28573000000), ('PaymentsToAcquirePropertyPlantAndEquipment', 95487000000), ('PaymentsRelatedToTaxWithholdingForShareBasedCompensation', 24377000000), ('UnrecognizedTaxBenefitsDecreasesResultingFromSettlementsWithTaxingAuthorities', 462000000), ('AdjustmentsRelatedToTaxWithholdingForShareBasedCompensation', 48754000000), ('IncreaseDecreaseInPrepaidDeferredExpenseAndOtherAssets', -23000000), ('InterestExpenseNonoperating', 1346000000), ('EarningsPerShareBasic', 48.43), ('IncreaseDecreaseInAccountsPayableTrade', 634000000), ('InterestExpenseDebt', 1263000000), ('DeferredIncomeTaxesAndTaxCredits', -7893000000), ('EffectiveIncomeTaxRateReconciliationNondeductibleExpenseShareBasedCompensationCost', -0.017), ('StockRepurchasedAndRetiredDuringPeriodValue', 107463000000), ('UnrecognizedTaxBenefitsReductionsResultingFromLapseOfApplicableStatuteOfLimitations', 88000000), ('ProceedsFromPaymentsForOtherFinancingActivities', -44000000), ('OtherNoncashIncomeExpense', -1363000000), ('VariableLeaseCost', 1787000000), ('Depreciation', 58760000000.0), ('SellingAndMarketingExpense', 38910000000), ('GoodwillOtherIncreaseDecrease', -18000000), ('IncomeTaxesPaidNet', 23568000000), ('CurrentForeignTaxExpenseBenefit', 7312000000), ('CapitalExpendituresIncurredButNotYetPaid', 14551000000), ('DepreciationDepletionAndAmortization', 35362000000), ('LeaseCost', 9269000000), ('TangibleAssetImpairmentCharges', 3036000000.0), ('DeferredForeignIncomeTaxExpenseBenefit', -140000000), ('OtherNonoperatingIncomeExpense', -299000000), ('EffectiveIncomeTaxRateContinuingOperations', 0.489), ('EffectiveIncomeTaxRateReconciliationTaxCreditsResearch', 0.068), ('DeferredStateAndLocalIncomeTaxExpenseBenefit', -325000000), ('StockRepurchasedAndRetiredDuringPeriodShares', 318000000), ('NetCashProvidedByUsedInOperatingActivities', 212916000000), ('IncomeTaxExpenseBenefit', 22252000000), ('NonoperatingIncomeExpense', 1835000000), ('AdvertisingExpense', 6730000000.0), ('AdjustmentsToAdditionalPaidInCapitalSharebasedCompensationRequisiteServicePeriodRecognitionValue', 42709000000), ('PaymentsOfDividends', 10143000000), ('OtherComprehensiveIncomeLossForeignCurrencyTransactionAndTranslationAdjustmentNetOfTax', -1979000000), ('OperatingLeaseCost', 6307000000), ('EarningsPerShareDiluted', 47.32), ('GoodwillAcquiredDuringPeriod', 357000000), ('NetIncomeLossAttributableToParentDiluted', 124658000000), ('ImpairmentOfLongLivedAssetsHeldForUse', 9683000000), ('NetCashProvidedByUsedInInvestingActivities', -100615000000), ('InvestmentIncomeInterest', 4617000000), ('CostOfRevenue', 81369000000), ('IncomeLossFromContinuingOperationsBeforeIncomeTaxesDomestic', 134866000000), ('DeferredFederalIncomeTaxExpenseBenefit', -7418000000), ('GeneralAndAdministrativeExpense', 32964000000), ('NetCashProvidedByUsedInFinancingActivities', -82417000000), ('ProceedsFromSaleAndMaturityOfMarketableSecuri ...
#
#
# Total metrics in context: 2
# c-43_c-44_c-45_c-89_c-91_c-92_c-93_c-94_c-95_c-96_c-97_c-98_c-99_c-100_c-101_c-102_c-90_c-103_c-130_c-218_c-219_c-220
# [('RestructuringCharges', 20682000000), ('RestructuringAndRelatedCostExpectedNumberOfPositionsEliminated', 11000)]
#
#
# Total metrics in context: 8
# c-47_c-289_c-290
# [('ShareBasedCompensationArrangementByShareBasedPaymentAwardEquityInstrumentsOtherThanOptionsVestedInPeriodWeightedAverageGrantDateFairValue', 250.76), ('ShareBasedCompensationArrangementByShareBasedPaymentAwardEquityInstrumentsOtherThanOptionsGrantsInPeriodWeightedAverageGrantDateFairValue', 904.9200000000001), ('ShareBasedCompensationArrangementByShareBasedPaymentAwardEquityInstrumentsOtherThanOptionsVestedInPeriodTotalFairValue', 60040000000), ('ShareBasedCompensationArrangementByShareBasedPaymentAwardEquityInstrumentsOtherThanOptionsVestedInPeriod', 64769000), ('EmployeeServiceShareBasedCompensationTaxBenefitFromCompensationExpense', 12600000000), ('ShareBasedCompensationArrangementByShareBasedPaymentAwardEquityInstrumentsOtherThanOptionsForfeituresWeightedAverageGrantDateFairValue', 255.04), ('ShareBasedCompensationArrangementByShareBasedPaymentAwardEquityInstrumentsOtherThanOptionsGrantsInPeriod', 48661000), ('ShareBasedCompensationArrangementByShareBasedPaymentAwardEquityInstrumentsOtherThanOptionsForfeitedInPeriod', 10322000)]
#
#
# Total metrics in context: 1
# c-56_c-57_c-58
# [('ConcentrationRiskPercentage1', 1.13)]
#
#
# Total metrics in context: 1
# c-104_c-105_c-106_c-107_c-108_c-109_c-110_c-111_c-112_c-113_c-114_c-115_c-116_c-117_c-118_c-119_c-120_c-121_c-122_c-123_c-124_c-125_c-126_c-127_c-128_c-129
# [('RestructuringAndRelatedCostCostIncurredToDate1', 35160000000)]
#
#
# Total metrics in context: 1
# c-131_c-132
# [('AntidilutiveSecuritiesExcludedFromComputationOfEarningsPerShareAmount', 111000000)]
#
#
# Total metrics in context: 1
# c-201_c-202_c-203_c-204_c-205_c-206_c-207_c-208_c-209_c-210_c-211_c-212
# [('PropertyPlantAndEquipmentGross', 284815000000)]
#
#
# Total metrics in context: 1
# c-216_c-217
# [('InterestCostsCapitalized', 667000000)]
#
#
# Total metrics in context: 0
#
# Total metrics in context: 0
#
# Total metrics in context: 1
# c-241_c-242_c-243
# [('DebtInstrumentFaceAmount', 58000000000.0)]
#
#
# Total metrics in context: 2
# c-244_c-245_c-248_c-249_c-252_c-253
# [('DebtInstrumentInterestRateEffectivePercentage', 0.2883), ('DebtInstrumentInterestRateStatedPercentage', 0.2835)]
#
#
# Total metrics in context: 1
# c-256_c-257
# [('LongTermDebtFairValue', 46310000000)]
#
#
# Total metrics in context: 1
# c-258
# [('LitigationSettlementAmountAwardedToOtherParty', 725000000)]
#
#
# Total metrics in context: 1
# c-259
# [('LossContingencyClaimsDismissedNumber', 1)]
#
#
# Total metrics in context: 1
# c-260
# [('LossContingencyAccrualPayments', 5000000000)]
#
#
# Total metrics in context: 1
# c-262
# [('LossContingencyAccrualAtCarryingValue', 1200000000)]
#
#
# Total metrics in context: 1
# c-264
# [('LossContingencyNewClaimsFiledNumber', 4)]
#
#
# Total metrics in context: 1
# c-274
# [('CommonStockCapitalSharesReservedForFutureIssuance', 483000000)]
#
#
# Total metrics in context: 2
# c-287_c-288
# [('ShareBasedCompensationArrangementByShareBasedPaymentAwardEquityInstrumentsOtherThanOptionsNonvestedNumber', 271694000), ('ShareBasedCompensationArrangementByShareBasedPaymentAwardEquityInstrumentsOtherThanOptionsNonvestedWeightedAverageGrantDateFairValue', 512.12)]
#
#
# Total metrics in context: 2
# c-291_c-292
# [('TaxCreditCarryforwardAmount', 6065000000), ('OperatingLossCarryforwards', 2360000000)]
#
#
# Total metrics in context: 1
# c-293_c-294
# [('IncomeTaxExaminationEstimateOfPossibleLoss', 9680000000)]
#
# ✓ Created and exported to: bal_sheet_meta_data.csv
# ✓ Created and exported to: inc_cf_meta_data.csv
# ✓ Created and exported to: meta_data.csv
# ✓ Appended to: meta_data.csv
# ✓ Appended to: meta_data.csv
# ✓ Appended to: meta_data.csv
# ✓ Appended to: meta_data.csv
# ✓ Appended to: meta_data.csv
# ✓ Appended to: inc_cf_meta_data.csv
# ✓ Appended to: meta_data.csv
# ✓ Appended to: meta_data.csv
# ✓ Appended to: bal_sheet_meta_data.csv
# ✓ Appended to: meta_data.csv
# ✓ Appended to: meta_data.csv
# ✓ Appended to: meta_data.csv
# ✓ Appended to: meta_data.csv
# ✓ Appended to: meta_data.csv
# ✓ Appended to: meta_data.csv
# ✓ Appended to: meta_data.csv
# ✓ Appended to: meta_data.csv
# ✓ Appended to: meta_data.csv
