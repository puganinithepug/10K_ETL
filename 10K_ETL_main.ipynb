# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import LinearSVC
from sklearn.metrics import confusion_matrix
from sklearn.calibration import CalibratedClassifierCV

from sklearn.model_selection import train_test_split

import numpy as np

# imports for pipeline to run
import requests
import re
import unicodedata
import os
import warnings

import logging

import argparse

import math

import matplotlib_inline

import os
import shutil

# for fetching previosu pipeline steps
import importlib

# previous pipeline step
import NLP_Sort_10K_W4 as NLP

# updated
importlib.reload(NLP)

# run pipeline, clean up

def organize_files_after_run(ticker, new_dir, files_to_move):
    
    os.makedirs(new_dir, exist_ok=True)
    
    # List of files to move (adjust these to match your actual filenames)
    
    # Move each file into the new directory
    for file in files_to_move:
        source = file
        destination = os.path.join(new_dir, file)
        
        if os.path.exists(source):
            shutil.move(source, destination)
            print(f"Moved: {source} → {destination}")
        else:
            print(f"File not found: {source}")
    
    print(f"Done! Files moved to '{new_dir}'")

def main():

    ticker = NLP.main()
    
    new_dir_W1= "parsed_xbrl_data_W1"
    # SEC_contextRefs_{ticker}.csv
    # sec_xbrl_content_{ticker}.csv
    # sec_xbrl_contexts_{ticker}.csv
    # sec_xbrl_facts_{ticker}.csv
    # sec_xbrl_values_{ticker}.csv
    files_W1=[f"SEC_contextRefs_{ticker}.csv", f"sec_xbrl_content_{ticker}.csv", f"sec_xbrl_contexts_{ticker}.csv", f"sec_xbrl_facts_{ticker}.csv", f"sec_xbrl_values_{ticker}.csv"]

    new_dir_W2 = "merged_data_W2"
    # merged_sec_xbrl_{ticker}.csv
    files_W2 = [f"merged_sec_xbrl_{ticker}.csv"]

    new_dir_W3 = "sorted_inc&cf_bal_data_W3"
    #inc_cf_{ticker}_data.csv
    #bal_sheet_{ticker}_data.csv
    #{ticker}_data.csv
    files_W3 = [f"inc_cf_{ticker}_data.csv", f"bal_sheet_{ticker}_data.csv", f"{ticker}_data.csv"]
    
    new_dir_W4 = "nlp_classified_inc_cf_bal_data_W4"
    #uncertain_bal_sheet_{ticker}.csv
    #uncertain_inc_cf_{ticker}.csv
    #nlp_inc_cf_{ticker}.csv
    #nlp_inc_{ticker}.csv
    #nlp_cf_{ticker}.csv
    #nlp_bal_sheet_{ticker}_data.csv
    files_W4 = [f"uncertain_bal_sheet_{ticker}.csv", f"uncertain_inc_cf_{ticker}.csv", f"nlp_inc_cf_{ticker}.csv", f"nlp_inc_{ticker}.csv", f"nlp_cf_{ticker}.csv", f"nlp_bal_sheet_{ticker}_data.csv"]

    organize = [(new_dir_W1, files_W1), (new_dir_W2, files_W2), (new_dir_W3, files_W3), (new_dir_W4, files_W4)]

    for n_d, f in organize:
        organize_files_after_run(ticker, n_d, f)
    
if __name__ == "__main__":
    main()
# Out:
# Company ticker:  aapl
# Year:  2020
# Found CIK 0000320193 for ticker aapl
# https://data.sec.gov/submissions/CIK0000320193.json
# DEBUG: 10-K filings for 2020: 1
#   - 2020-10-30: 10-K
# DEBUG: Checking year 2020, found 1 filings
# https://www.sec.gov/Archives/edgar/data/320193/000032019320000096/index.json
# Found filing with required XMLs at: https://www.sec.gov/Archives/edgar/data/320193/000032019320000096/index.json
# {'aapl-20200926_cal.xml': 'https://www.sec.gov/Archives/edgar/data/320193/000032019320000096/aapl-20200926_cal.xml', 'aapl-20200926_def.xml': 'https://www.sec.gov/Archives/edgar/data/320193/000032019320000096/aapl-20200926_def.xml', 'aapl-20200926_htm.xml': 'https://www.sec.gov/Archives/edgar/data/320193/000032019320000096/aapl-20200926_htm.xml', 'aapl-20200926_lab.xml': 'https://www.sec.gov/Archives/edgar/data/320193/000032019320000096/aapl-20200926_lab.xml', 'aapl-20200926_pre.xml': 'https://www.sec.gov/Archives/edgar/data/320193/000032019320000096/aapl-20200926_pre.xml'}
# Downloaded: aapl-20200926_cal.xml
# Downloaded: aapl-20200926_def.xml
# Downloaded: aapl-20200926_htm.xml
# Downloaded: aapl-20200926_lab.xml
# Downloaded: aapl-20200926_pre.xml
# DEBUG: uri_to_prefix has 11 entries
# DEBUG: Found 318 contexts and 9 units
# DEBUG: Found 1388 facts
# Created: sec_xbrl_content_aapl.csv, sec_xbrl_values_aapl.csv, sec_xbrl_contexts_aapl.csv, sec_xbrl_facts_aapl.csv
# ✓ Added to dict_csvs: sec_xbrl_content_aapl.csv
# ✓ Added to dict_csvs: sec_xbrl_values_aapl.csv
# ✓ Added to dict_csvs: sec_xbrl_contexts_aapl.csv
# ✓ Added to dict_csvs: sec_xbrl_facts_aapl.csv
#
# Total metrics in context: 0
#
# Total metrics in context: 2
#
# Total metrics in context: 110
#
# Total metrics in context: 129
#
# Total metrics in context: 1
#
# Total metrics in context: 1
#
# Total metrics in context: 1
#
# Total metrics in context: 2
#
# Total metrics in context: 1
#
# Total metrics in context: 2
#
# Total metrics in context: 1
#
# Total metrics in context: 1
#
# Total metrics in context: 1
#
# Total metrics in context: 1
#
# Total metrics in context: 1
#
# Total metrics in context: 1
#
# Total metrics in context: 1
#
# Total metrics in context: 1
#
# Total metrics in context: 1
#
# Total metrics in context: 0
#
# Total metrics in context: 1
#
# Total metrics in context: 2
#
# Total metrics in context: 1
#
# Total metrics in context: 2
#
# Total metrics in context: 3
#
# Total metrics in context: 1
#
# Total metrics in context: 1
#
# Total metrics in context: 0
# ✓ Created and exported to: aapl_data.csv
# ✓ Created and exported to: bal_sheet_aapl_data.csv
# ✓ Created and exported to: inc_cf_aapl_data.csv
# ✓ Appended to: aapl_data.csv
# ✓ Appended to: bal_sheet_aapl_data.csv
# ✓ Appended to: bal_sheet_aapl_data.csv
# ✓ Appended to: aapl_data.csv
# ✓ Appended to: aapl_data.csv
# ✓ Appended to: aapl_data.csv
# ✓ Appended to: aapl_data.csv
# ✓ Appended to: aapl_data.csv
# ✓ Appended to: aapl_data.csv
# ✓ Appended to: aapl_data.csv
# ✓ Appended to: aapl_data.csv
# ✓ Appended to: aapl_data.csv
# ✓ Appended to: aapl_data.csv
# ✓ Appended to: aapl_data.csv
# ✓ Appended to: aapl_data.csv
# ✓ Appended to: aapl_data.csv
# ✓ Appended to: aapl_data.csv
# ✓ Appended to: aapl_data.csv
# ✓ Appended to: aapl_data.csv
# ✓ Appended to: aapl_data.csv
# ✓ Appended to: aapl_data.csv
# ✓ Appended to: aapl_data.csv
# Confidence threshold (0.0-1.0):  0.4
# /home/phlka_pug/anaconda3/lib/python3.13/site-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# LogisticRegression: train=0.8734, val=0.6000
# MultinomialNB: train=0.8481, val=0.4857
# DecisionTreeClassifier: train=0.7848, val=0.2857
# /home/phlka_pug/anaconda3/lib/python3.13/site-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# /home/phlka_pug/anaconda3/lib/python3.13/site-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# LogisticRegression: train=0.9848, val=0.8276
# LogisticRegression: train=0.8939, val=0.4483
# MultinomialNB: train=0.7576, val=0.4138
# DecisionTreeClassifier: train=0.6061, val=0.4483
# Income statement: 100 rows in nlp_inc_aapl.csv
# Cashflow statement: 29 rows in nlp_cf_aapl.csv
#
# ⚠ Found 90 uncertain predictions (threshold: 0.4):
#   Require manual review and annotation.
#
#                                                                                     label             value               category  prediction_confidence
#                                                        DerivativeFairValueOfDerivativeNet      -719,000,000   subtotal liabilities               0.174233
#                                                               CommitmentsAndContingencies               NaN      noncurrent assets               0.193358
#                                                  ShortTermDebtWeightedAverageInterestRate                 0      noncurrent assets               0.194457
#                                            DeferredTaxLiabilitiesOtherComprehensiveIncome       712,000,000                 equity               0.205935
#                                                 DeferredTaxLiabilitiesLeasingArrangements     1,862,000,000    current liabilities               0.206223
#                                                          LiabilitiesAndStockholdersEquity   662,404,000,000                 equity               0.208554
#                                                   StockRepurchaseProgramAuthorizedAmount1   225,000,000,000                 equity               0.211958
#                                                            StandardProductWarrantyAccrual    14,450,000,000      noncurrent assets               0.212711
#                                             DebtInstrumentInterestRateEffectivePercentage                 0      noncurrent assets               0.217242
#                                                           DeferredTaxAssetsLiabilitiesNet    16,202,000,000      noncurrent assets               0.217717
#                                                               DeferredTaxLiabilitiesOther     1,305,000,000    current liabilities               0.218751
#                                                DebtInstrumentInterestRateStatedPercentage                 0      noncurrent assets               0.221463
# EmployeeServiceShareBasedCompensationNonvestedAwardsTotalCompensationCostNotYetRecognized    12,200,000,000      noncurrent assets               0.226045
#                                                              DeferredIncomeTaxLiabilities    21,733,000,000      noncurrent assets               0.228487
#                                    LongTermDebtMaturitiesRepaymentsOfPrincipalInYearThree    11,389,000,000      noncurrent assets               0.229915
#                                                                              InventoryNet     8,167,000,000      noncurrent assets               0.232168
#                                                      DerivativeFairValueOfDerivativeAsset     8,588,000,000        subtotal assets               0.232750
#                                      LongTermDebtMaturitiesRepaymentsOfPrincipalInYearTwo     9,569,000,000      noncurrent assets               0.233998
#                                     LongTermDebtMaturitiesRepaymentsOfPrincipalInYearFour    10,115,000,000      noncurrent assets               0.234270
#                                     LongTermDebtMaturitiesRepaymentsOfPrincipalInYearFive    10,914,000,000      noncurrent assets               0.240998
#                                  LongTermDebtMaturitiesRepaymentsOfPrincipalAfterYearFive    55,341,000,000      noncurrent assets               0.247597
#                                                                                    Assets   662,404,000,000      noncurrent assets               0.251614
#                                                                NontradeReceivablesCurrent    44,203,000,000    current liabilities               0.253949
#                                    DeferredTaxAssetsTaxDeferredExpenseReservesAndAccruals    10,130,000,000      noncurrent assets               0.256056
#                                                               MarketableSecuritiesCurrent   209,280,000,000         current assets               0.257043
#                                UnrecordedUnconditionalPurchaseObligationDueAfterFiveYears       130,000,000    current liabilities               0.261125
#                                                                   OperatingLeaseLiability     9,181,000,000   subtotal liabilities               0.261172
#                                                                               Liabilities   506,577,000,000    current liabilities               0.263018
#                             LongTermDebtMaturitiesRepaymentsOfPrincipalInNextTwelveMonths     8,750,000,000    current liabilities               0.263335
#                                                              DebtInstrumentCarryingAmount   521,614,000,000 noncurrent liabilities               0.263397
#                                                                    DeferredTaxAssetsGross    39,723,000,000      noncurrent assets               0.265968
#                                                                     FinanceLeaseLiability       661,000,000    current liabilities               0.267477
#                                                         OtherAccruedLiabilitiesNoncurrent    47,278,000,000    current liabilities               0.270275
#                                                                    DeferredTaxAssetsOther     4,583,000,000      noncurrent assets               0.270513
#                                           AccumulatedOtherComprehensiveIncomeLossNetOfTax      -990,000,000                 equity               0.272258
#                                                       DeferredTaxAssetsValuationAllowance     1,788,000,000      noncurrent assets               0.273296
#                                                        RetainedEarningsAccumulatedDeficit    60,864,000,000                 equity               0.275606
#                                                                     LiabilitiesNoncurrent   295,467,000,000 noncurrent liabilities               0.278149
#                                                           DeferredTaxAssetsDeferredIncome     3,010,000,000      noncurrent assets               0.278884
#                                                                     RestrictedInvestments    37,500,000,000      noncurrent assets               0.280253
#                                                  DerivativeFairValueOfDerivativeLiability     7,199,000,000   subtotal liabilities               0.283079
#                                                              AccruedIncomeTaxesNoncurrent    57,715,000,000 noncurrent liabilities               0.284268
#                               UnrecordedUnconditionalPurchaseObligationBalanceSheetAmount     8,652,000,000    current liabilities               0.285035
#                       UnrecordedUnconditionalPurchaseObligationBalanceOnSecondAnniversary     2,885,000,000    current liabilities               0.286205
#                               UnrecognizedTaxBenefitsIncomeTaxPenaltiesAndInterestAccrued     2,700,000,000 noncurrent liabilities               0.286466
#                                                                        StockholdersEquity   792,188,000,000                 equity               0.288110
#                                                                     LongTermDebtFairValue   224,600,000,000 noncurrent liabilities               0.288615
#                       UnrecordedUnconditionalPurchaseObligationBalanceOnFourthAnniversary       357,000,000    current liabilities               0.290213
#                        UnrecordedUnconditionalPurchaseObligationBalanceOnFirstAnniversary     3,476,000,000    current liabilities               0.292853
#                        UnrecordedUnconditionalPurchaseObligationBalanceOnThirdAnniversary     1,700,000,000    current liabilities               0.293081
#                        UnrecordedUnconditionalPurchaseObligationBalanceOnFifthAnniversary       104,000,000    current liabilities               0.294556
#                                                RestrictedCashAndCashEquivalentsNoncurrent     3,094,000,000         current assets               0.295974
#                                                                      DeferredTaxAssetsNet    37,935,000,000      noncurrent assets               0.298192
#                                                              AccountsReceivableNetCurrent    39,046,000,000         current assets               0.300898
#                                                                OtherLiabilitiesNoncurrent   104,993,000,000 noncurrent liabilities               0.301514
#                                                                        OtherAssetsCurrent    23,616,000,000         current assets               0.306228
#                                             FinanceLeaseLiabilityUndiscountedExcessAmount       429,000,000   subtotal liabilities               0.307196
#                                                             OperatingLeaseRightOfUseAsset     8,570,000,000      noncurrent assets               0.309156
#                                                            PropertyPlantAndEquipmentGross   398,966,000,000      noncurrent assets               0.309396
#                                                              PropertyPlantAndEquipmentNet    74,144,000,000      noncurrent assets               0.313351
#                                     DecreaseInUnrecognizedTaxBenefitsIsReasonablyPossible     3,900,000,000 noncurrent liabilities               0.315352
#                                                          FinanceLeaseLiabilityPaymentsDue     1,090,000,000    current liabilities               0.316280
#                                             FinanceLeaseLiabilityPaymentsDueAfterYearFive       895,000,000 noncurrent liabilities               0.317298
#                                                                       LongTermDebtCurrent    19,033,000,000    current liabilities               0.317735
#                                                                             AssetsCurrent   306,532,000,000         current assets               0.318939
#                                                     CashAndCashEquivalentsAtCarryingValue   212,535,000,000         current assets               0.326259
#                                              CommonStocksIncludingAdditionalPaidInCapital    95,953,000,000                 equity               0.328251
#                                                  AvailableForSaleSecuritiesDebtSecurities 1,145,139,000,000      noncurrent assets               0.328841
#                                                                          AssetsNoncurrent   355,872,000,000      noncurrent assets               0.329461
#                                                                           CommercialPaper    21,976,000,000    current liabilities               0.334888
#                                           RestrictedCashAndCashEquivalentsAtCarryingValue        59,000,000         current assets               0.336835
#                                                  LesseeOperatingLeaseLiabilityPaymentsDue    10,144,000,000 noncurrent liabilities               0.337067
#                                    UnrecognizedTaxBenefitsThatWouldImpactEffectiveTaxRate    17,400,000,000 noncurrent liabilities               0.344703
#                                                                   UnrecognizedTaxBenefits    82,295,000,000 noncurrent liabilities               0.344804
#                                          AvailableForSaleDebtSecuritiesAmortizedCostBasis 1,135,179,000,000      noncurrent assets               0.345739
#                                                             ContractWithCustomerLiability    18,300,000,000    current liabilities               0.347954
#                                     LesseeOperatingLeaseLiabilityPaymentsDueAfterYearFive     3,845,000,000 noncurrent liabilities               0.348041
#                             CashCashEquivalentsRestrictedCashAndRestrictedCashEquivalents   136,215,000,000         current assets               0.348092
#                                                            MarketableSecuritiesNoncurrent   412,456,000,000      noncurrent assets               0.349381
#                                                                    LongTermDebtNoncurrent   190,474,000,000 noncurrent liabilities               0.349611
#                                     LesseeOperatingLeaseLiabilityUndiscountedExcessAmount       963,000,000   subtotal liabilities               0.350280
#                                              DeferredTaxAssetsGoodwillAndIntangibleAssets    19,962,000,000      noncurrent assets               0.351801
#                     AvailableForSaleDebtSecuritiesAccumulatedGrossUnrealizedGainBeforeTax     7,964,000,000      noncurrent assets               0.354276
#                           DebtInstrumentUnamortizedDiscountPremiumAndDebtIssuanceCostsNet       538,000,000      noncurrent assets               0.357622
#                     AvailableForSaleDebtSecuritiesAccumulatedGrossUnrealizedLossBeforeTax     1,332,000,000      noncurrent assets               0.363953
#                                                                     OtherAssetsNoncurrent    75,500,000,000      noncurrent assets               0.364517
#                                                                    AccountsPayableCurrent    88,532,000,000    current liabilities               0.367095
#                                                                          NoncurrentAssets   148,288,000,000      noncurrent assets               0.372126
#                                  LesseeOperatingLeaseLiabilityPaymentsDueNextTwelveMonths     1,493,000,000    current liabilities               0.383670
#                                                           FinanceLeaseLiabilityNoncurrent       637,000,000 noncurrent liabilities               0.397991
#
# ✓ Uncertain predictions saved to: uncertain_bal_sheet_aapl.csv
#   Please review and manually annotate these predictions.
#
# ⚠ Found 115 uncertain predictions (threshold: 0.4):
#   Require manual review and annotation.
#
#                                                                                                                                     label             value statement  statement_confidence              category  category_confidence
#                                                                                            StandardProductWarrantyAccrualWarrantiesIssued    10,448,000,000    income              0.572476  operating activities             0.111227
#                                                                                                                                  Revenues       571,000,000    income              0.725210    Operating Expenses             0.111544
#                                                                                                       InvestmentIncomeInterestAndDividend    14,410,000,000    income              0.623338  financing activities             0.112752
#                                                                                                      CommonStockDividendsPerShareDeclared                 2    income              0.682135  financing activities             0.115444
#                                                                                                    DeferredForeignIncomeTaxExpenseBenefit     7,230,000,000    income              0.725384    Operating Expenses             0.115866
#                                                                                                EffectiveIncomeTaxRateContinuingOperations                 0    income              0.727446  comprehensive income             0.116128
#                                                                     AntidilutiveSecuritiesExcludedFromComputationOfEarningsPerShareAmount        62,000,000    income              0.704545  comprehensive income             0.116409
#                                               IncomeLossFromContinuingOperationsBeforeIncomeTaxesExtraordinaryItemsNoncontrollingInterest   208,666,000,000    income              0.747258  comprehensive income             0.116522
#                                                                                                           DeferredIncomeTaxExpenseBenefit   -33,145,000,000    income              0.727258    Operating Expenses             0.116738
#                                                                                       RevenueFromContractWithCustomerExcludingAssessedTax 4,260,374,000,000    income              0.674781  operating activities             0.116823
#                                                                                        ForeignIncomeTaxExpenseBenefitContinuingOperations    18,312,000,000    income              0.743614    Operating Expenses             0.117236
#                                                                                                                           InterestPaidNet     9,447,000,000    income              0.641987    Operating Expenses             0.117255
#                                                             IncomeTaxReconciliationIncomeTaxExpenseBenefitAtFederalStatutoryIncomeTaxRate    45,784,000,000    income              0.732445  comprehensive income             0.117491
#                                                                                                    DeferredFederalIncomeTaxExpenseBenefit   -40,377,000,000    income              0.725444    Operating Expenses             0.119255
#                                                                                              DeferredStateAndLocalIncomeTaxExpenseBenefit         2,000,000    income              0.722692    Operating Expenses             0.119564
#                                                                                  StateAndLocalIncomeTaxExpenseBenefitContinuingOperations     1,483,000,000    income              0.740617    Operating Expenses             0.119790
#                                                                                        FederalIncomeTaxExpenseBenefitContinuingOperations    13,738,000,000    income              0.743441    Operating Expenses             0.119862
#                                                                                                                               GrossProfit   508,535,000,000    income              0.613603  comprehensive income             0.120764
#                                                                                                                CostOfGoodsAndServicesSold   989,128,000,000    income              0.638798    Operating Expenses             0.121812
#                                                                                            ContractWithCustomerLiabilityRevenueRecognized    16,700,000,000    income              0.673990               Revenue             0.121882
#                                                                                                                   IncomeTaxExpenseBenefit    33,533,000,000    income              0.728716    Operating Expenses             0.122046
#                                                                        DefinedContributionPlanMaximumAnnualContributionsPerEmployeeAmount            19,500    income              0.621710  comprehensive income             0.122577
#                                                                                                 IncomeTaxReconciliationTaxCreditsResearch     1,836,000,000    income              0.687234  comprehensive income             0.124610
#                                                             UnrecognizedTaxBenefitsDecreasesResultingFromSettlementsWithTaxingAuthorities     1,693,000,000    income              0.591181  operating activities             0.124771
#                                                                                                                        IncomeTaxesPaidNet    35,181,000,000    income              0.666916  comprehensive income             0.125260
#                                                                      UnrecognizedTaxBenefitsDecreasesResultingFromPriorPeriodTaxPositions     3,689,000,000    income              0.600097  comprehensive income             0.125680
#                                                                                                           CurrentForeignTaxExpenseBenefit    11,082,000,000    income              0.715767    Operating Expenses             0.126297
#                                                                      UnrecognizedTaxBenefitsIncreasesResultingFromPriorPeriodTaxPositions     8,730,000,000    income              0.610189  comprehensive income             0.127926
#                                                       UnrecognizedTaxBenefitsReductionsResultingFromLapseOfApplicableStatuteOfLimitations       148,000,000    income              0.655738  comprehensive income             0.128938
#                            CashCashEquivalentsRestrictedCashAndRestrictedCashEquivalentsPeriodIncreaseDecreaseIncludingExchangeRateEffect    19,500,000,000  cashflow              0.631703  operating activities             0.129423
#                                                                                                     CurrentStateAndLocalTaxExpenseBenefit     1,481,000,000    income              0.706197    Operating Expenses             0.130499
#                                                                                                           CurrentFederalTaxExpenseBenefit    54,115,000,000    income              0.709602    Operating Expenses             0.130992
#                                                                                           IncomeTaxReconciliationStateAndLocalIncomeTaxes       694,000,000    income              0.699461  comprehensive income             0.132436
#                                                                       EffectiveIncomeTaxRateReconciliationAtFederalStatutoryIncomeTaxRate                 0    income              0.705866  comprehensive income             0.132633
#                                                                                IncomeLossFromContinuingOperationsBeforeIncomeTaxesForeign   130,400,000,000    income              0.737590  comprehensive income             0.132792
#                                                                                   IncomeTaxReconciliationForeignIncomeTaxRateDifferential   -10,765,000,000    income              0.700912  comprehensive income             0.133823
#                                                                                                            ProceedsFromOtherShortTermDebt     5,200,000,000  cashflow              0.502452  financing activities             0.134522
#                                                                                           PaymentsToAcquireAvailableForSaleSecuritiesDebt   225,924,000,000    income              0.562396  comprehensive income             0.137154
#                                                                                    ProceedsFromShortTermDebtMaturingInMoreThanThreeMonths    34,614,000,000  cashflow              0.505126  financing activities             0.137855
#                                                                                                                       OperatingIncomeLoss   735,980,000,000    income              0.775454 nonoperating expenses             0.139756
#                                                                         EffectiveIncomeTaxRateReconciliationTaxCutsAndJobsActOf2017Amount       933,000,000    income              0.698155  comprehensive income             0.139858
#                                                                                          ProceedsFromSaleOfAvailableForSaleSecuritiesDebt   155,299,000,000    income              0.613360  comprehensive income             0.141084
#                                                                     ProceedsFromMaturitiesPrepaymentsAndCallsOfAvailableForSaleSecurities   165,901,000,000    income              0.573784  comprehensive income             0.141568
#                                                                               UnrecognizedTaxBenefitsIncomeTaxPenaltiesAndInterestExpense       647,000,000    income              0.747780    Operating Expenses             0.141678
#                                                                                                                                 Dividends    41,951,000,000    income              0.566284  financing activities             0.141752
#                                                                    UnrecognizedTaxBenefitsIncreasesResultingFromCurrentPeriodTaxPositions     4,868,000,000    income              0.636402  comprehensive income             0.143697
#                                                                                                    StandardProductWarrantyAccrualPayments    10,928,000,000  cashflow              0.512876  financing activities             0.144110
#                                                                                                                     InterestCostsIncurred     9,000,000,000    income              0.695785 nonoperating expenses             0.146614
#                                                              GainLossFromComponentsExcludedFromAssessmentOfFairValueHedgeEffectivenessNet     1,242,000,000    income              0.649136  comprehensive income             0.148616
#                                                                                                     StockIssuedDuringPeriodValueNewIssues     2,330,000,000    income              0.535542  financing activities             0.149598
#                                                                                   WeightedAverageNumberDilutedSharesOutstandingAdjustment       479,335,000    income              0.700261    earnings per share             0.149967
#                                                                                    RepaymentsOfShortTermDebtMaturingInMoreThanThreeMonths    39,487,000,000    income              0.529763  financing activities             0.150914
#                                                                                                            RepaymentsOfOtherShortTermDebt     5,200,000,000    income              0.525078  financing activities             0.157827
#                                                                                                   IncomeTaxReconciliationOtherAdjustments       544,000,000    income              0.644738  comprehensive income             0.157940
#                                                                                                NetCashProvidedByUsedInInvestingActivities    57,673,000,000  cashflow              0.622842  investing activities             0.160422
#                                                                                              PaymentsToAcquireBusinessesNetOfCashAcquired     2,869,000,000  cashflow              0.570642  operating activities             0.164306
#                                                                                                                     EarningsPerShareBasic                15    income              0.724537    earnings per share             0.166760
#                                                                                                                             NetIncomeLoss   284,865,000,000    income              0.774507            net income             0.166921
#                                                                                                                   EarningsPerShareDiluted                15    income              0.720150    earnings per share             0.172239
#                                                                                             WeightedAverageNumberOfSharesOutstandingBasic    55,644,965,000    income              0.725188    earnings per share             0.173952
#                                                                                                        ProceedsFromIssuanceOfLongTermDebt    30,023,000,000  cashflow              0.523749  financing activities             0.175517
# ShareBasedCompensationArrangementByShareBasedPaymentAwardEquityInstrumentsOtherThanOptionsGrantsInPeriodWeightedAverageGrantDateFairValue               153    income              0.629006    Operating Expenses             0.176309
#                                                                                           WeightedAverageNumberOfDilutedSharesOutstanding    56,124,300,000    income              0.721699    earnings per share             0.176421
#                                                                                   OciBeforeReclassificationsBeforeTaxAttributableToParent    10,500,000,000    income              0.734218  comprehensive income             0.176833
# ShareBasedCompensationArrangementByShareBasedPaymentAwardEquityInstrumentsOtherThanOptionsVestedInPeriodWeightedAverageGrantDateFairValue               101    income              0.628396    Operating Expenses             0.177349
#                                                                                                                  RepaymentsOfLongTermDebt    27,934,000,000    income              0.517265  financing activities             0.177730
#                                                                        ProceedsFromRepaymentsOfShortTermDebtMaturingInMoreThanThreeMonths    -4,873,000,000  cashflow              0.543749  financing activities             0.178447
#    ShareBasedCompensationArrangementByShareBasedPaymentAwardEquityInstrumentsOtherThanOptionsForfeituresWeightedAverageGrantDateFairValue               120    income              0.641275    Operating Expenses             0.180311
#                                                                                                NetCashProvidedByUsedInOperatingActivities   227,499,000,000  cashflow              0.596655  operating activities             0.181159
#                                                                          ProceedsFromRepaymentsOfShortTermDebtMaturingInThreeMonthsOrLess    -2,104,000,000  cashflow              0.546430  financing activities             0.182305
#                                                                                                         PaymentsToAcquireOtherInvestments     3,082,000,000  cashflow              0.610820  investing activities             0.182684
#                                                                                                                    OperatingLeasePayments     1,500,000,000    income              0.658199  comprehensive income             0.185274
#                    ShareBasedCompensationArrangementByShareBasedPaymentAwardEquityInstrumentsOtherThanOptionsVestedInPeriodTotalFairValue    27,000,000,000    income              0.604274    Operating Expenses             0.187964
#                                                                                                                         OperatingExpenses   104,071,000,000    income              0.717912    Operating Expenses             0.189188
#                                                                                                NetCashProvidedByUsedInFinancingActivities  -265,672,000,000  cashflow              0.607118  financing activities             0.189664
#                                                                                                         ProceedsFromIssuanceOfCommonStock     2,330,000,000    income              0.502268  financing activities             0.190801
#                                                                                                                           InterestExpense     9,689,000,000    income              0.743136    Operating Expenses             0.191076
#                               ShareBasedCompensationArrangementByShareBasedPaymentAwardEquityInstrumentsOtherThanOptionsForfeitedInPeriod        60,151,000    income              0.610227    Operating Expenses             0.191712
#                                                                                                                 OtherNoncashIncomeExpense     1,193,000,000    income              0.572469  operating activities             0.192172
#                                  ShareBasedCompensationArrangementByShareBasedPaymentAwardEquityInstrumentsOtherThanOptionsGrantsInPeriod       485,611,000    income              0.611780    Operating Expenses             0.193061
#                                                                                           ProceedsFromPaymentsForOtherFinancingActivities      -231,000,000  cashflow              0.605288  financing activities             0.194404
#                                  ShareBasedCompensationArrangementByShareBasedPaymentAwardEquityInstrumentsOtherThanOptionsVestedInPeriod       504,966,000    income              0.611004    Operating Expenses             0.194505
#                                                                                                             OperatingLeasesRentExpenseNet     2,500,000,000    income              0.724959    Operating Expenses             0.201094
#                                                          EffectiveIncomeTaxRateReconciliationShareBasedCompensationExcessTaxBenefitAmount    -2,244,000,000    income              0.733100    Operating Expenses             0.202020
#                                                                                              StockRepurchasedAndRetiredDuringPeriodShares     5,042,287,000  cashflow              0.519357  financing activities             0.204043
#                                                                                                   ProceedsFromRepaymentsOfCommercialPaper    -6,977,000,000  cashflow              0.565339  financing activities             0.207384
#                                                                                           PaymentsForProceedsFromOtherInvestingActivities     2,614,000,000  cashflow              0.613837  investing activities             0.216278
#                                                                                               StockRepurchasedAndRetiredDuringPeriodValue   285,173,000,000  cashflow              0.533019  financing activities             0.216684
#                                          AdjustmentsToAdditionalPaidInCapitalSharebasedCompensationRequisiteServicePeriodRecognitionValue    18,612,000,000  cashflow              0.517022           disclosures             0.222744
#                                                                                                PaymentsToAcquirePropertyPlantAndEquipment    31,117,000,000  cashflow              0.567168  operating activities             0.224587
#                                                                                                      DepreciationDepletionAndAmortization    34,506,000,000    income              0.695873    Operating Expenses             0.227563
#                                                                               AdjustmentsRelatedToTaxWithholdingForShareBasedCompensation     9,611,000,000    income              0.683843    Operating Expenses             0.233093
#                                                                                                        PaymentsForRepurchaseOfCommonStock   211,993,000,000  cashflow              0.521966  financing activities             0.233370
#                                                                                  PaymentsRelatedToTaxWithholdingForShareBasedCompensation    18,578,000,000    income              0.673200    Operating Expenses             0.238532
#                                                                        ReclassificationFromAociCurrentPeriodBeforeTaxAttributableToParent     2,986,000,000    income              0.717103  comprehensive income             0.239746
#                                                                                                                       PaymentsOfDividends    41,912,000,000  cashflow              0.549128  financing activities             0.243282
#                                                                                      SharesPaidForTaxWithholdingForShareBasedCompensation       179,000,000    income              0.707955    Operating Expenses             0.243590
#                                                                                                                              Depreciation    30,300,000,000    income              0.698418    Operating Expenses             0.247010
#                                                                                                    SellingGeneralAndAdministrativeExpense    54,866,000,000    income              0.709846    Operating Expenses             0.257838
#                                                                                                             ResearchAndDevelopmentExpense    49,205,000,000    income              0.702875    Operating Expenses             0.258883
#                                                                                             ProceedsFromSaleAndMaturityOfOtherInvestments     2,079,000,000  cashflow              0.599515  investing activities             0.264048
#                                                                    EmployeeServiceShareBasedCompensationTaxBenefitFromCompensationExpense     6,336,000,000    income              0.724303    Operating Expenses             0.276717
#                                                                                                                 NonoperatingIncomeExpense     4,471,000,000    income              0.762134 nonoperating expenses             0.293332
#                                                                                                            OtherNonoperatingIncomeExpense      -106,000,000    income              0.752100 nonoperating expenses             0.294396
#                                                                                                                        OperatingLeaseCost     1,500,000,000    income              0.735232    Operating Expenses             0.301321
#                                                                                                                    ShareBasedCompensation    18,237,000,000    income              0.715234    Operating Expenses             0.315427
#                                                                                           IncreaseDecreaseInContractWithCustomerLiability     1,453,000,000  cashflow              0.558041  operating activities             0.319264
#                                                                                                                         VariableLeaseCost     9,300,000,000    income              0.713823    Operating Expenses             0.324218
#                                                                                                    AllocatedShareBasedCompensationExpense    18,237,000,000    income              0.729610    Operating Expenses             0.327421
#                                                                                               IncreaseDecreaseInOtherOperatingLiabilities    42,665,000,000  cashflow              0.610085  operating activities             0.347390
#                                            OtherComprehensiveIncomeLossDerivativeExcludedComponentIncreaseDecreaseBeforeAdjustmentsAndTax      -168,000,000    income              0.651919  comprehensive income             0.352008
#                                                                                                    IncreaseDecreaseInOtherOperatingAssets     9,138,000,000  cashflow              0.606622  operating activities             0.353243
#                                                        OtherComprehensiveIncomeUnrealizedGainLossOnDerivativesArisingDuringPeriodNetOfTax      -138,000,000    income              0.763632  comprehensive income             0.359096
#                                                  OtherComprehensiveIncomeUnrealizedHoldingGainLossOnSecuritiesArisingDuringPeriodNetOfTax     1,597,000,000    income              0.756684  comprehensive income             0.364475
#                                                                                                        IncreaseDecreaseInOtherReceivables     3,526,000,000  cashflow              0.629838  operating activities             0.367231
#
# ✓ Uncertain predictions saved to: uncertain_inc_cf_aapl.csv
#   Please review and manually annotate these predictions.
# Moved: SEC_contextRefs_aapl.csv → parsed_xbrl_data_W1/SEC_contextRefs_aapl.csv
# Moved: sec_xbrl_content_aapl.csv → parsed_xbrl_data_W1/sec_xbrl_content_aapl.csv
# Moved: sec_xbrl_contexts_aapl.csv → parsed_xbrl_data_W1/sec_xbrl_contexts_aapl.csv
# Moved: sec_xbrl_facts_aapl.csv → parsed_xbrl_data_W1/sec_xbrl_facts_aapl.csv
# Moved: sec_xbrl_values_aapl.csv → parsed_xbrl_data_W1/sec_xbrl_values_aapl.csv
# Done! Files moved to 'parsed_xbrl_data_W1'
# Moved: merged_sec_xbrl_aapl.csv → merged_data_W2/merged_sec_xbrl_aapl.csv
# Done! Files moved to 'merged_data_W2'
# Moved: inc_cf_aapl_data.csv → sorted_inc&cf_bal_data_W3/inc_cf_aapl_data.csv
# Moved: bal_sheet_aapl_data.csv → sorted_inc&cf_bal_data_W3/bal_sheet_aapl_data.csv
# Moved: aapl_data.csv → sorted_inc&cf_bal_data_W3/aapl_data.csv
# Done! Files moved to 'sorted_inc&cf_bal_data_W3'
# Moved: uncertain_bal_sheet_aapl.csv → nlp_classified_inc_cf_bal_data_W4/uncertain_bal_sheet_aapl.csv
# Moved: uncertain_inc_cf_aapl.csv → nlp_classified_inc_cf_bal_data_W4/uncertain_inc_cf_aapl.csv
# Moved: nlp_inc_cf_aapl.csv → nlp_classified_inc_cf_bal_data_W4/nlp_inc_cf_aapl.csv
# Moved: nlp_inc_aapl.csv → nlp_classified_inc_cf_bal_data_W4/nlp_inc_aapl.csv
# Moved: nlp_cf_aapl.csv → nlp_classified_inc_cf_bal_data_W4/nlp_cf_aapl.csv
# Moved: nlp_bal_sheet_aapl_data.csv → nlp_classified_inc_cf_bal_data_W4/nlp_bal_sheet_aapl_data.csv
# Done! Files moved to 'nlp_classified_inc_cf_bal_data_W4'
