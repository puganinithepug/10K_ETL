# %%
# LIQUIDITY = current ratio, quick ratio
#def liquidity():
    # current_ratio = (current_assets)/(current_liabilities)
    # quick_ratio = (cash + accounts_receivable + short_term_investments)/(current_liabilities)
    
#PROFITABILITY = gross profit margin, net profit margin, return on assets, return on equity
#def profitability():
    # earnings_after_tax = EAT
    # gross_profit_margin = ((net_rev- dir_exp)/net_rev)*100%
    # net_profit_margin = (net_income/rev)*100%
    # ret_on_asset = ((EAT)/tot_assets)*100%
    # ret_on_equity = (EAT/shareholder_equity)*100%
    
# ACTIVITY = average days inventory, inventory turnover, average collection period, average days payable, cash conversion cycle
#def activity():
    # also known as efficiency
    # for av_days_inv 
    # av_inv = (start_inv_bal + end_inv_bal)/_2
    # av_days_inv = (av_inv)*[days]/(COGS)

    #av collection period ratio
    
    #AR = accounts receivable
    #av_AR = (start_AR + end_AR)/2
    # rev = revenue
    #av_days_receivable = av_AR*days/rev
    
    #AP = accounts payable
    # av_AP = (start_AP + end_AP)/2
    #av_days_payable = av_AP*days/COGS
    
    # cash conversion cycle
    #  convert its cash on hand into inventory
    # inventory_turnover = COGS/av_inv
    
# LEVERAGE = debt to equity, debt to assets, debt coverage ratio
#def leverage():
    #debt_to_equity = tot_liabilities/shareholder_equity
    #debt_to_asset = tot_liabilities/assets
    #debt_service_coverage = EBITDA/(interest+principal)

#visualisation of data with matplolib
